# %% [markdown]
# # Change LAIs 2G & 3G cells in Nokia & Ercisson's MSSs

# %% [markdown]
# ## Import modules

# %%
# Import modules (NOK_ERI_Toolkit) & others that will be needed along the program
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import NOK_ERI_Toolkit as NOK_ERI_Toolkit
from datetime import datetime

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load 2G & 3G data form "Change LAI - Python Template.xlsx"

# %%
# Especify the path to the file and read the template
path_to_file = 'C:/Users/Alvaro/OneDrive/My Files/_Scripts_Models/Commands Generators/Change LAI - Python Template.xlsx'
xls = pd.ExcelFile(path_to_file)                                                                                            #Read excel file

# %%
# Create DataFrame for 2G Nokia data & clean it up
df_nok_2g = pd.read_excel(xls, sheet_name='NOK_2G', dtype=str) #Read specific sheet | dtype=str forces to read as string to avoid lose '0s'
df_nok_2g['New CGI'] = df_nok_2g['MCC'] + '-' + df_nok_2g['MNC'] + '-' + df_nok_2g['New LAC'] + '-' + df_nok_2g['CI/SA']    # Create col New_CGI
df_nok_2g['DE-PARA'] = 'de LAC=' + df_nok_2g['LAC'] + ' para LAC=' + df_nok_2g['New LAC']                                   # Create col DE-PARA
df_nok_2g = df_nok_2g.sort_values(by=['MSS', 'Municipio', 'NE', 'CELL_NAME'], ignore_index=True)                            # Sort DataFrame

# %%
# Create DataFrame for 3G Nokia data & clean it up
df_nok_3g = pd.read_excel(xls, sheet_name='NOK_3G', dtype=str) #Read specific sheet | dtype=str forces to read as string to avoid lose '0s'
df_nok_3g['New CGI'] = df_nok_3g['MCC'] + '-' + df_nok_3g['MNC'] + '-' + df_nok_3g['New LAC'] + '-' + df_nok_3g['CI/SA']    # Create col New_CGI
df_nok_3g['DE-PARA'] = 'de LAC=' + df_nok_3g['LAC'] + ' para LAC=' + df_nok_3g['New LAC']                                   # Create col DE-PARA
df_nok_3g = df_nok_3g.sort_values(by=['MSS', 'Municipio', 'NE', 'CELL_NAME'], ignore_index=True)                            # Sort DataFrame

# %%
# Create DataFrame for 2G Ericsson data & clean it up
df_eri_2g = pd.read_excel(xls, sheet_name='ERI_2G', dtype=str) #Read specific sheet | dtype=str forces to read as string to avoid lose '0s'
df_eri_2g['New CGI'] = df_eri_2g['MCC'] + '-' + df_eri_2g['MNC'] + '-' + df_eri_2g['New LAC'] + '-' + df_eri_2g['CI/SA']    # Create col New_CGI
df_eri_2g['DE-PARA'] = 'de LAC=' + df_eri_2g['LAC'] + ' para LAC=' + df_eri_2g['New LAC']                                   # Create col DE-PARA
df_eri_2g = df_eri_2g.sort_values(by=['MSS', 'Municipio', 'NE', 'CELL_NAME'], ignore_index=True)                            # Sort DataFrame

# %%
# Create DataFrame for 3G Ericsson data & clean it up
df_eri_3g = pd.read_excel(xls, sheet_name='ERI_3G', dtype=str) #Read specific sheet | dtype=str forces to read as string to avoid lose '0s'
df_eri_3g['New CGI'] = df_eri_3g['MCC'] + '-' + df_eri_3g['MNC'] + '-' + df_eri_3g['New LAC'] + '-' + df_eri_3g['CI/SA']    # Create col New_CGI
df_eri_3g['DE-PARA'] = 'de LAC=' + df_eri_3g['LAC'] + ' para LAC=' + df_eri_3g['New LAC']                                   # Create col DE-PARA
df_eri_3g = df_eri_3g.sort_values(by=['MSS', 'Municipio', 'NE', 'CELL_NAME'], ignore_index=True)                            # Sort DataFrame

# %% [markdown]
# ## Print 2G & 3G Nokia's (change & fallback) commands

# %%
# Get 2G Nokia's change commands
NOK_ERI_Toolkit.change_lai_2g_nok(my_df=df_nok_2g, my_cmd='change')
# Out:
# ! Feira | Change de LAC=1475 para LAC=21975
# !--------------------------------------------------------------------------------------
# ZEPO:NAME=BAXXX011;
# ZEPO:NAME=BAXXX011;
# ZEPS:NAME=BAXXX011:L;
# ZEPS:NAME=BAXXX011:L;
# ZEPB:NAME=BAXXX011:BSCNAME=BSCBAXX:MCC=724,MNC=05,LAC=21975;
# ZEPB:NAME=BAXXX011:BSCNAME=BSCBAXX:MCC=724,MNC=05,LAC=21975;
# ZEPS:NAME=BAXXX011:U;
# ZEPS:NAME=BAXXX011:U;
# True

# %%
# Get 2G Nokia's fallback commands
NOK_ERI_Toolkit.change_lai_2g_nok(my_df=df_nok_2g, my_cmd='fallback')
# Out:
# ! Feira | Fallback de LAC=1475 para LAC=21975
# !--------------------------------------------------------------------------------------
# ZEPO:NAME=BAXXX011;
# ZEPO:NAME=BAXXX011;
# ZEPS:NAME=BAXXX011:L;
# ZEPS:NAME=BAXXX011:L;
# ZEPB:NAME=BAXXX011:BSCNAME=BSCBAXX:MCC=724,MNC=05,LAC=1475;
# ZEPB:NAME=BAXXX011:BSCNAME=BSCBAXX:MCC=724,MNC=05,LAC=1475;
# ZEPS:NAME=BAXXX011:U;
# ZEPS:NAME=BAXXX011:U;
# True

# %%
# Get 3G Nokia's change commands
NOK_ERI_Toolkit.change_lai_3g_nok(my_df=df_nok_3g, my_cmd='change')
# Out:
# ! ANTÔNIO CARDOSO | Change de LAC=30575 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBAATC01A;
# ZEPO:TYPE=SA,NAME=UBAATC01B;
# ZEPO:TYPE=SA,NAME=UBAATC01C;
# ZEPS:TYPE=SA,NAME=UBAATC01A:L;
# ZEPS:TYPE=SA,NAME=UBAATC01B:L;
# ZEPS:TYPE=SA,NAME=UBAATC01C:L;
# ZEPF:TYPE=SA,SANAME=UBAATC01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAATC01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAATC01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPS:TYPE=SA,NAME=UBAATC01A:U;
# ZEPS:TYPE=SA,NAME=UBAATC01B:U;
# ZEPS:TYPE=SA,NAME=UBAATC01C:U;
#
# ! ANTÔNIO GONÇALVES | Change de LAC=30474 para LAC=50074
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBAAVS01A;
# ZEPO:TYPE=SA,NAME=UBAAVS01B;
# ZEPO:TYPE=SA,NAME=UBAAVS01C;
# ZEPO:TYPE=SA,NAME=UBAAVS01E;
# ZEPO:TYPE=SA,NAME=UBAAVS01F;
# ZEPO:TYPE=SA,NAME=UBAAVS01G;
# ZEPS:TYPE=SA,NAME=UBAAVS01A:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01B:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01C:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01E:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01F:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01G:L;
# ZEPF:TYPE=SA,SANAME=UBAAVS01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=50074;
# ZEPF:TYPE=SA,SANAME=UBAAVS01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=50074;
# ZEPF:TYPE=SA,SANAME=UBAAVS01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=50074;
# ZEPF:TYPE=SA,SANAME=UBAAVS01E:MGWNBR=MSS:MCC=724,MNC=05,LAC=50074;
# ZEPF:TYPE=SA,SANAME=UBAAVS01F:MGWNBR=MSS:MCC=724,MNC=05,LAC=50074;
# ZEPF:TYPE=SA,SANAME=UBAAVS01G:MGWNBR=MSS:MCC=724,MNC=05,LAC=50074;
# ZEPS:TYPE=SA,NAME=UBAAVS01A:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01B:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01C:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01E:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01F:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01G:U;
#
# ! CARDEAL DA SILVA | Change de LAC=30775 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBACSW01A;
# ZEPO:TYPE=SA,NAME=UBACSW01B;
# ZEPO:TYPE=SA,NAME=UBACSW01C;
# ZEPO:TYPE=SA,NAME=UBACSW0301;
# ZEPO:TYPE=SA,NAME=UBACSW0302;
# ZEPO:TYPE=SA,NAME=UBACSW0303;
# ZEPO:TYPE=SA,NAME=UBACSW0351;
# ZEPO:TYPE=SA,NAME=UBACSW0352;
# ZEPO:TYPE=SA,NAME=UBACSW0353;
# ZEPS:TYPE=SA,NAME=UBACSW01A:L;
# ZEPS:TYPE=SA,NAME=UBACSW01B:L;
# ZEPS:TYPE=SA,NAME=UBACSW01C:L;
# ZEPS:TYPE=SA,NAME=UBACSW0301:L;
# ZEPS:TYPE=SA,NAME=UBACSW0302:L;
# ZEPS:TYPE=SA,NAME=UBACSW0303:L;
# ZEPS:TYPE=SA,NAME=UBACSW0351:L;
# ZEPS:TYPE=SA,NAME=UBACSW0352:L;
# ZEPS:TYPE=SA,NAME=UBACSW0353:L;
# ZEPF:TYPE=SA,SANAME=UBACSW01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW0301:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW0302:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW0303:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW0351:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW0352:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBACSW0353:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPS:TYPE=SA,NAME=UBACSW01A:U;
# ZEPS:TYPE=SA,NAME=UBACSW01B:U;
# ZEPS:TYPE=SA,NAME=UBACSW01C:U;
# ZEPS:TYPE=SA,NAME=UBACSW0301:U;
# ZEPS:TYPE=SA,NAME=UBACSW0302:U;
# ZEPS:TYPE=SA,NAME=UBACSW0303:U;
# ZEPS:TYPE=SA,NAME=UBACSW0351:U;
# ZEPS:TYPE=SA,NAME=UBACSW0352:U;
# ZEPS:TYPE=SA,NAME=UBACSW0353:U;
#
# ! LAMARÃO | Change de LAC=30575 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBALAR01A;
# ZEPO:TYPE=SA,NAME=UBALAR01B;
# ZEPO:TYPE=SA,NAME=UBALAR01C;
# ZEPO:TYPE=SA,NAME=UBALAR01E;
# ZEPO:TYPE=SA,NAME=UBALAR01F;
# ZEPO:TYPE=SA,NAME=UBALAR01G;
# ZEPO:TYPE=SA,NAME=UBALAR13A;
# ZEPO:TYPE=SA,NAME=UBALAR13B;
# ZEPO:TYPE=SA,NAME=UBALAR13C;
# ZEPO:TYPE=SA,NAME=UBALAR13E;
# ZEPO:TYPE=SA,NAME=UBALAR13F;
# ZEPO:TYPE=SA,NAME=UBALAR13G;
# ZEPS:TYPE=SA,NAME=UBALAR01A:L;
# ZEPS:TYPE=SA,NAME=UBALAR01B:L;
# ZEPS:TYPE=SA,NAME=UBALAR01C:L;
# ZEPS:TYPE=SA,NAME=UBALAR01E:L;
# ZEPS:TYPE=SA,NAME=UBALAR01F:L;
# ZEPS:TYPE=SA,NAME=UBALAR01G:L;
# ZEPS:TYPE=SA,NAME=UBALAR13A:L;
# ZEPS:TYPE=SA,NAME=UBALAR13B:L;
# ZEPS:TYPE=SA,NAME=UBALAR13C:L;
# ZEPS:TYPE=SA,NAME=UBALAR13E:L;
# ZEPS:TYPE=SA,NAME=UBALAR13F:L;
# ZEPS:TYPE=SA,NAME=UBALAR13G:L;
# ZEPF:TYPE=SA,SANAME=UBALAR01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR01E:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR01F:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR01G:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR13A:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR13B:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR13C:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR13E:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR13F:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBALAR13G:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPS:TYPE=SA,NAME=UBALAR01A:U;
# ZEPS:TYPE=SA,NAME=UBALAR01B:U;
# ZEPS:TYPE=SA,NAME=UBALAR01C:U;
# ZEPS:TYPE=SA,NAME=UBALAR01E:U;
# ZEPS:TYPE=SA,NAME=UBALAR01F:U;
# ZEPS:TYPE=SA,NAME=UBALAR01G:U;
# ZEPS:TYPE=SA,NAME=UBALAR13A:U;
# ZEPS:TYPE=SA,NAME=UBALAR13B:U;
# ZEPS:TYPE=SA,NAME=UBALAR13C:U;
# ZEPS:TYPE=SA,NAME=UBALAR13E:U;
# ZEPS:TYPE=SA,NAME=UBALAR13F:U;
# ZEPS:TYPE=SA,NAME=UBALAR13G:U;
#
# ! MILAGRES | Change de LAC=30475 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBAMLG01A;
# ZEPO:TYPE=SA,NAME=UBAMLG01B;
# ZEPO:TYPE=SA,NAME=UBAMLG01C;
# ZEPO:TYPE=SA,NAME=UBAMLG01I;
# ZEPO:TYPE=SA,NAME=UBAMLG01J;
# ZEPO:TYPE=SA,NAME=UBAMLG01K;
# ZEPO:TYPE=SA,NAME=UBAMLG02A;
# ZEPO:TYPE=SA,NAME=UBAMLG02B;
# ZEPO:TYPE=SA,NAME=UBAMLG02C;
# ZEPO:TYPE=SA,NAME=UBAMLG02E;
# ZEPO:TYPE=SA,NAME=UBAMLG02F;
# ZEPO:TYPE=SA,NAME=UBAMLG02G;
# ZEPS:TYPE=SA,NAME=UBAMLG01A:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01B:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01C:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01I:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01J:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01K:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02A:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02B:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02C:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02E:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02F:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02G:L;
# ZEPF:TYPE=SA,SANAME=UBAMLG01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG01I:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG01J:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG01K:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG02A:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG02B:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG02C:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG02E:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG02F:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPF:TYPE=SA,SANAME=UBAMLG02G:MGWNBR=MSS:MCC=724,MNC=05,LAC=51775;
# ZEPS:TYPE=SA,NAME=UBAMLG01A:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01B:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01C:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01I:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01J:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01K:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02A:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02B:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02C:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02E:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02F:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02G:U;
# True

# %%
# Get 3G Nokia's fallback commands
NOK_ERI_Toolkit.change_lai_3g_nok(my_df=df_nok_3g, my_cmd='fallback')
# Out:
# ! ANTÔNIO CARDOSO | Fallbac de LAC=30575 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBAATC01A;
# ZEPO:TYPE=SA,NAME=UBAATC01B;
# ZEPO:TYPE=SA,NAME=UBAATC01C;
# ZEPS:TYPE=SA,NAME=UBAATC01A:L;
# ZEPS:TYPE=SA,NAME=UBAATC01B:L;
# ZEPS:TYPE=SA,NAME=UBAATC01C:L;
# ZEPF:TYPE=SA,SANAME=UBAATC01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBAATC01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBAATC01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPS:TYPE=SA,NAME=UBAATC01A:U;
# ZEPS:TYPE=SA,NAME=UBAATC01B:U;
# ZEPS:TYPE=SA,NAME=UBAATC01C:U;
#
# ! ANTÔNIO GONÇALVES | Fallbac de LAC=30474 para LAC=50074
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBAAVS01A;
# ZEPO:TYPE=SA,NAME=UBAAVS01B;
# ZEPO:TYPE=SA,NAME=UBAAVS01C;
# ZEPO:TYPE=SA,NAME=UBAAVS01E;
# ZEPO:TYPE=SA,NAME=UBAAVS01F;
# ZEPO:TYPE=SA,NAME=UBAAVS01G;
# ZEPS:TYPE=SA,NAME=UBAAVS01A:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01B:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01C:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01E:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01F:L;
# ZEPS:TYPE=SA,NAME=UBAAVS01G:L;
# ZEPF:TYPE=SA,SANAME=UBAAVS01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30474;
# ZEPF:TYPE=SA,SANAME=UBAAVS01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30474;
# ZEPF:TYPE=SA,SANAME=UBAAVS01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30474;
# ZEPF:TYPE=SA,SANAME=UBAAVS01E:MGWNBR=MSS:MCC=724,MNC=05,LAC=30474;
# ZEPF:TYPE=SA,SANAME=UBAAVS01F:MGWNBR=MSS:MCC=724,MNC=05,LAC=30474;
# ZEPF:TYPE=SA,SANAME=UBAAVS01G:MGWNBR=MSS:MCC=724,MNC=05,LAC=30474;
# ZEPS:TYPE=SA,NAME=UBAAVS01A:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01B:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01C:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01E:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01F:U;
# ZEPS:TYPE=SA,NAME=UBAAVS01G:U;
#
# ! CARDEAL DA SILVA | Fallbac de LAC=30775 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBACSW01A;
# ZEPO:TYPE=SA,NAME=UBACSW01B;
# ZEPO:TYPE=SA,NAME=UBACSW01C;
# ZEPO:TYPE=SA,NAME=UBACSW0301;
# ZEPO:TYPE=SA,NAME=UBACSW0302;
# ZEPO:TYPE=SA,NAME=UBACSW0303;
# ZEPO:TYPE=SA,NAME=UBACSW0351;
# ZEPO:TYPE=SA,NAME=UBACSW0352;
# ZEPO:TYPE=SA,NAME=UBACSW0353;
# ZEPS:TYPE=SA,NAME=UBACSW01A:L;
# ZEPS:TYPE=SA,NAME=UBACSW01B:L;
# ZEPS:TYPE=SA,NAME=UBACSW01C:L;
# ZEPS:TYPE=SA,NAME=UBACSW0301:L;
# ZEPS:TYPE=SA,NAME=UBACSW0302:L;
# ZEPS:TYPE=SA,NAME=UBACSW0303:L;
# ZEPS:TYPE=SA,NAME=UBACSW0351:L;
# ZEPS:TYPE=SA,NAME=UBACSW0352:L;
# ZEPS:TYPE=SA,NAME=UBACSW0353:L;
# ZEPF:TYPE=SA,SANAME=UBACSW01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW0301:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW0302:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW0303:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW0351:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW0352:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPF:TYPE=SA,SANAME=UBACSW0353:MGWNBR=MSS:MCC=724,MNC=05,LAC=30775;
# ZEPS:TYPE=SA,NAME=UBACSW01A:U;
# ZEPS:TYPE=SA,NAME=UBACSW01B:U;
# ZEPS:TYPE=SA,NAME=UBACSW01C:U;
# ZEPS:TYPE=SA,NAME=UBACSW0301:U;
# ZEPS:TYPE=SA,NAME=UBACSW0302:U;
# ZEPS:TYPE=SA,NAME=UBACSW0303:U;
# ZEPS:TYPE=SA,NAME=UBACSW0351:U;
# ZEPS:TYPE=SA,NAME=UBACSW0352:U;
# ZEPS:TYPE=SA,NAME=UBACSW0353:U;
#
# ! LAMARÃO | Fallbac de LAC=30575 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBALAR01A;
# ZEPO:TYPE=SA,NAME=UBALAR01B;
# ZEPO:TYPE=SA,NAME=UBALAR01C;
# ZEPO:TYPE=SA,NAME=UBALAR01E;
# ZEPO:TYPE=SA,NAME=UBALAR01F;
# ZEPO:TYPE=SA,NAME=UBALAR01G;
# ZEPO:TYPE=SA,NAME=UBALAR13A;
# ZEPO:TYPE=SA,NAME=UBALAR13B;
# ZEPO:TYPE=SA,NAME=UBALAR13C;
# ZEPO:TYPE=SA,NAME=UBALAR13E;
# ZEPO:TYPE=SA,NAME=UBALAR13F;
# ZEPO:TYPE=SA,NAME=UBALAR13G;
# ZEPS:TYPE=SA,NAME=UBALAR01A:L;
# ZEPS:TYPE=SA,NAME=UBALAR01B:L;
# ZEPS:TYPE=SA,NAME=UBALAR01C:L;
# ZEPS:TYPE=SA,NAME=UBALAR01E:L;
# ZEPS:TYPE=SA,NAME=UBALAR01F:L;
# ZEPS:TYPE=SA,NAME=UBALAR01G:L;
# ZEPS:TYPE=SA,NAME=UBALAR13A:L;
# ZEPS:TYPE=SA,NAME=UBALAR13B:L;
# ZEPS:TYPE=SA,NAME=UBALAR13C:L;
# ZEPS:TYPE=SA,NAME=UBALAR13E:L;
# ZEPS:TYPE=SA,NAME=UBALAR13F:L;
# ZEPS:TYPE=SA,NAME=UBALAR13G:L;
# ZEPF:TYPE=SA,SANAME=UBALAR01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR01E:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR01F:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR01G:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR13A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR13B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR13C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR13E:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR13F:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPF:TYPE=SA,SANAME=UBALAR13G:MGWNBR=MSS:MCC=724,MNC=05,LAC=30575;
# ZEPS:TYPE=SA,NAME=UBALAR01A:U;
# ZEPS:TYPE=SA,NAME=UBALAR01B:U;
# ZEPS:TYPE=SA,NAME=UBALAR01C:U;
# ZEPS:TYPE=SA,NAME=UBALAR01E:U;
# ZEPS:TYPE=SA,NAME=UBALAR01F:U;
# ZEPS:TYPE=SA,NAME=UBALAR01G:U;
# ZEPS:TYPE=SA,NAME=UBALAR13A:U;
# ZEPS:TYPE=SA,NAME=UBALAR13B:U;
# ZEPS:TYPE=SA,NAME=UBALAR13C:U;
# ZEPS:TYPE=SA,NAME=UBALAR13E:U;
# ZEPS:TYPE=SA,NAME=UBALAR13F:U;
# ZEPS:TYPE=SA,NAME=UBALAR13G:U;
#
# ! MILAGRES | Fallbac de LAC=30475 para LAC=51775
# !--------------------------------------------------------------------------------------
# ZEPO:TYPE=SA,NAME=UBAMLG01A;
# ZEPO:TYPE=SA,NAME=UBAMLG01B;
# ZEPO:TYPE=SA,NAME=UBAMLG01C;
# ZEPO:TYPE=SA,NAME=UBAMLG01I;
# ZEPO:TYPE=SA,NAME=UBAMLG01J;
# ZEPO:TYPE=SA,NAME=UBAMLG01K;
# ZEPO:TYPE=SA,NAME=UBAMLG02A;
# ZEPO:TYPE=SA,NAME=UBAMLG02B;
# ZEPO:TYPE=SA,NAME=UBAMLG02C;
# ZEPO:TYPE=SA,NAME=UBAMLG02E;
# ZEPO:TYPE=SA,NAME=UBAMLG02F;
# ZEPO:TYPE=SA,NAME=UBAMLG02G;
# ZEPS:TYPE=SA,NAME=UBAMLG01A:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01B:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01C:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01I:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01J:L;
# ZEPS:TYPE=SA,NAME=UBAMLG01K:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02A:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02B:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02C:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02E:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02F:L;
# ZEPS:TYPE=SA,NAME=UBAMLG02G:L;
# ZEPF:TYPE=SA,SANAME=UBAMLG01A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG01B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG01C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG01I:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG01J:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG01K:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG02A:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG02B:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG02C:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG02E:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG02F:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPF:TYPE=SA,SANAME=UBAMLG02G:MGWNBR=MSS:MCC=724,MNC=05,LAC=30475;
# ZEPS:TYPE=SA,NAME=UBAMLG01A:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01B:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01C:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01I:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01J:U;
# ZEPS:TYPE=SA,NAME=UBAMLG01K:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02A:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02B:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02C:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02E:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02F:U;
# ZEPS:TYPE=SA,NAME=UBAMLG02G:U;
# True

# %% [markdown]
# ## Print 2G & 3G Ericsson's (change & fallback) commands

# %%
# Get 2G Ericsson's change commands
NOK_ERI_Toolkit.change_lai_2g_eri(my_df=df_eri_2g, my_cmd='change')
# Out:
# ! LAJEDÃO | Change de LAC=21973 para LAC=20473
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9XXX011;
# MGCEP:CELL=9XXX011;
# MGRCP:CELL=9XXX011;
# MGRCP:CELL=9XXX011;
# MGCEE:CELL=9XXX011;
# MGCEE:CELL=9XXX011;
# MGCEI:CELL=9XXX011,BSC=BSCBAXX,CGI=724-05-20473-142;
# MGCEI:CELL=9XXX011,BSC=BSCBAXX,CGI=724-05-20473-30142;
# MGCEC:CELL=9XXX011,EA=73;
# MGCEC:CELL=9XXX011,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
# True

# %%
# Get 2G Ericsson's fallback commands
NOK_ERI_Toolkit.change_lai_2g_eri(my_df=df_eri_2g, my_cmd='fallback')
# Out:
# ! LAJEDÃO | Fallback de LAC=21973 para LAC=20473
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9XXX011;
# MGCEP:CELL=9XXX011;
# MGRCP:CELL=9XXX011;
# MGRCP:CELL=9XXX011;
# MGCEE:CELL=9XXX011;
# MGCEE:CELL=9XXX011;
# MGCEI:CELL=9XXX011,BSC=BSCBAXX,CGI=724-05-21973-142;
# MGCEI:CELL=9XXX011,BSC=BSCBAXX,CGI=724-05-21973-30142;
# MGCEC:CELL=9XXX011,EA=73;
# MGCEC:CELL=9XXX011,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
# True

# %%
# Get 3G Ericsson's change commands
NOK_ERI_Toolkit.change_lai_3g_eri(my_df=df_eri_3g, my_cmd='change')
# Out:
# ! ARATACA | Change de LAC=30173 para LAC=51373
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IATW01A;
# MGAAP:AREA=IATW01B;
# MGAAP:AREA=IATW01C;
# MGAAP:AREA=IATW01E;
# MGAAP:AREA=IATW01F;
# MGAAP:AREA=IATW01G;
# MGRCP:AREA=IATW01A;
# MGRCP:AREA=IATW01B;
# MGRCP:AREA=IATW01C;
# MGRCP:AREA=IATW01E;
# MGRCP:AREA=IATW01F;
# MGRCP:AREA=IATW01G;
# MGAAE:AREA=IATW01A;
# MGAAE:AREA=IATW01B;
# MGAAE:AREA=IATW01C;
# MGAAE:AREA=IATW01E;
# MGAAE:AREA=IATW01F;
# MGAAE:AREA=IATW01G;
# MGAAI:AREA=IATW01A,SAI=724-05-51373-61050;
# MGAAI:AREA=IATW01B,SAI=724-05-51373-61051;
# MGAAI:AREA=IATW01C,SAI=724-05-51373-61052;
# MGAAI:AREA=IATW01E,SAI=724-05-51373-64650;
# MGAAI:AREA=IATW01F,SAI=724-05-51373-64651;
# MGAAI:AREA=IATW01G,SAI=724-05-51373-64652;
# MGAAC:AREA=IATW01A,EA=73;
# MGAAC:AREA=IATW01B,EA=73;
# MGAAC:AREA=IATW01C,EA=73;
# MGAAC:AREA=IATW01E,EA=73;
# MGAAC:AREA=IATW01F,EA=73;
# MGAAC:AREA=IATW01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! FLORESTA AZUL | Change de LAC=30173 para LAC=51173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IFAL01A;
# MGAAP:AREA=IFAL01B;
# MGAAP:AREA=IFAL01C;
# MGAAP:AREA=IFAL01E;
# MGAAP:AREA=IFAL01F;
# MGAAP:AREA=IFAL01G;
# MGRCP:AREA=IFAL01A;
# MGRCP:AREA=IFAL01B;
# MGRCP:AREA=IFAL01C;
# MGRCP:AREA=IFAL01E;
# MGRCP:AREA=IFAL01F;
# MGRCP:AREA=IFAL01G;
# MGAAE:AREA=IFAL01A;
# MGAAE:AREA=IFAL01B;
# MGAAE:AREA=IFAL01C;
# MGAAE:AREA=IFAL01E;
# MGAAE:AREA=IFAL01F;
# MGAAE:AREA=IFAL01G;
# MGAAI:AREA=IFAL01A,SAI=724-05-51173-60470;
# MGAAI:AREA=IFAL01B,SAI=724-05-51173-60471;
# MGAAI:AREA=IFAL01C,SAI=724-05-51173-60472;
# MGAAI:AREA=IFAL01E,SAI=724-05-51173-64653;
# MGAAI:AREA=IFAL01F,SAI=724-05-51173-64654;
# MGAAI:AREA=IFAL01G,SAI=724-05-51173-64655;
# MGAAC:AREA=IFAL01A,EA=73;
# MGAAC:AREA=IFAL01B,EA=73;
# MGAAC:AREA=IFAL01C,EA=73;
# MGAAC:AREA=IFAL01E,EA=73;
# MGAAC:AREA=IFAL01F,EA=73;
# MGAAC:AREA=IFAL01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! ITAPÉ | Change de LAC=30173 para LAC=51173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IYPE03A;
# MGAAP:AREA=IYPE03B;
# MGAAP:AREA=IYPE03C;
# MGRCP:AREA=IYPE03A;
# MGRCP:AREA=IYPE03B;
# MGRCP:AREA=IYPE03C;
# MGAAE:AREA=IYPE03A;
# MGAAE:AREA=IYPE03B;
# MGAAE:AREA=IYPE03C;
# MGAAI:AREA=IYPE03A,SAI=724-05-51173-61056;
# MGAAI:AREA=IYPE03B,SAI=724-05-51173-61057;
# MGAAI:AREA=IYPE03C,SAI=724-05-51173-61058;
# MGAAC:AREA=IYPE03A,EA=73;
# MGAAC:AREA=IYPE03B,EA=73;
# MGAAC:AREA=IYPE03C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! PAU BRASIL | Change de LAC=30173 para LAC=51173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IPSL01A;
# MGAAP:AREA=IPSL01B;
# MGAAP:AREA=IPSL01C;
# MGAAP:AREA=IPSL01E;
# MGAAP:AREA=IPSL01F;
# MGAAP:AREA=IPSL01G;
# MGRCP:AREA=IPSL01A;
# MGRCP:AREA=IPSL01B;
# MGRCP:AREA=IPSL01C;
# MGRCP:AREA=IPSL01E;
# MGRCP:AREA=IPSL01F;
# MGRCP:AREA=IPSL01G;
# MGAAE:AREA=IPSL01A;
# MGAAE:AREA=IPSL01B;
# MGAAE:AREA=IPSL01C;
# MGAAE:AREA=IPSL01E;
# MGAAE:AREA=IPSL01F;
# MGAAE:AREA=IPSL01G;
# MGAAI:AREA=IPSL01A,SAI=724-05-51173-30307;
# MGAAI:AREA=IPSL01B,SAI=724-05-51173-31307;
# MGAAI:AREA=IPSL01C,SAI=724-05-51173-32307;
# MGAAI:AREA=IPSL01E,SAI=724-05-51173-64656;
# MGAAI:AREA=IPSL01F,SAI=724-05-51173-64657;
# MGAAI:AREA=IPSL01G,SAI=724-05-51173-64658;
# MGAAC:AREA=IPSL01A,EA=73;
# MGAAC:AREA=IPSL01B,EA=73;
# MGAAC:AREA=IPSL01C,EA=73;
# MGAAC:AREA=IPSL01E,EA=73;
# MGAAC:AREA=IPSL01F,EA=73;
# MGAAC:AREA=IPSL01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! BARRA DO ROCHA | Change de LAC=30273 para LAC=51273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IBHO01A;
# MGAAP:AREA=IBHO01B;
# MGAAP:AREA=IBHO01C;
# MGAAP:AREA=IBHO01E;
# MGAAP:AREA=IBHO01F;
# MGAAP:AREA=IBHO01G;
# MGRCP:AREA=IBHO01A;
# MGRCP:AREA=IBHO01B;
# MGRCP:AREA=IBHO01C;
# MGRCP:AREA=IBHO01E;
# MGRCP:AREA=IBHO01F;
# MGRCP:AREA=IBHO01G;
# MGAAE:AREA=IBHO01A;
# MGAAE:AREA=IBHO01B;
# MGAAE:AREA=IBHO01C;
# MGAAE:AREA=IBHO01E;
# MGAAE:AREA=IBHO01F;
# MGAAE:AREA=IBHO01G;
# MGAAI:AREA=IBHO01A,SAI=724-05-51273-60730;
# MGAAI:AREA=IBHO01B,SAI=724-05-51273-60731;
# MGAAI:AREA=IBHO01C,SAI=724-05-51273-60732;
# MGAAI:AREA=IBHO01E,SAI=724-05-51273-33677;
# MGAAI:AREA=IBHO01F,SAI=724-05-51273-33678;
# MGAAI:AREA=IBHO01G,SAI=724-05-51273-33679;
# MGAAC:AREA=IBHO01A,EA=73;
# MGAAC:AREA=IBHO01B,EA=73;
# MGAAC:AREA=IBHO01C,EA=73;
# MGAAC:AREA=IBHO01E,EA=73;
# MGAAC:AREA=IBHO01F,EA=73;
# MGAAC:AREA=IBHO01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! BOM JESUS DA SERRA | Change de LAC=30377 para LAC=53377
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IBJD03A;
# MGAAP:AREA=IBJD03B;
# MGAAP:AREA=IBJD03C;
# MGRCP:AREA=IBJD03A;
# MGRCP:AREA=IBJD03B;
# MGRCP:AREA=IBJD03C;
# MGAAE:AREA=IBJD03A;
# MGAAE:AREA=IBJD03B;
# MGAAE:AREA=IBJD03C;
# MGAAI:AREA=IBJD03A,SAI=724-05-53377-60038;
# MGAAI:AREA=IBJD03B,SAI=724-05-53377-60039;
# MGAAI:AREA=IBJD03C,SAI=724-05-53377-60040;
# MGAAC:AREA=IBJD03A,EA=77;
# MGAAC:AREA=IBJD03B,EA=77;
# MGAAC:AREA=IBJD03C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CAFARNAUM | Change de LAC=31074 para LAC=51374
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICFM01A;
# MGAAP:AREA=ICFM01B;
# MGAAP:AREA=ICFM01C;
# MGAAP:AREA=ICFM01M;
# MGAAP:AREA=ICFM01N;
# MGAAP:AREA=ICFM01O;
# MGRCP:AREA=ICFM01A;
# MGRCP:AREA=ICFM01B;
# MGRCP:AREA=ICFM01C;
# MGRCP:AREA=ICFM01M;
# MGRCP:AREA=ICFM01N;
# MGRCP:AREA=ICFM01O;
# MGAAE:AREA=ICFM01A;
# MGAAE:AREA=ICFM01B;
# MGAAE:AREA=ICFM01C;
# MGAAE:AREA=ICFM01M;
# MGAAE:AREA=ICFM01N;
# MGAAE:AREA=ICFM01O;
# MGAAI:AREA=ICFM01A,SAI=724-05-51374-60068;
# MGAAI:AREA=ICFM01B,SAI=724-05-51374-60069;
# MGAAI:AREA=ICFM01C,SAI=724-05-51374-60070;
# MGAAI:AREA=ICFM01M,SAI=724-05-51374-30075;
# MGAAI:AREA=ICFM01N,SAI=724-05-51374-30076;
# MGAAI:AREA=ICFM01O,SAI=724-05-51374-30077;
# MGAAC:AREA=ICFM01A,EA=74;
# MGAAC:AREA=ICFM01B,EA=74;
# MGAAC:AREA=ICFM01C,EA=74;
# MGAAC:AREA=ICFM01M,EA=74;
# MGAAC:AREA=ICFM01N,EA=74;
# MGAAC:AREA=ICFM01O,EA=74;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CARAÍBAS | Change de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICIZ02A;
# MGAAP:AREA=ICIZ02B;
# MGAAP:AREA=ICIZ02C;
# MGRCP:AREA=ICIZ02A;
# MGRCP:AREA=ICIZ02B;
# MGRCP:AREA=ICIZ02C;
# MGAAE:AREA=ICIZ02A;
# MGAAE:AREA=ICIZ02B;
# MGAAE:AREA=ICIZ02C;
# MGAAI:AREA=ICIZ02A,SAI=724-05-53977-60071;
# MGAAI:AREA=ICIZ02B,SAI=724-05-53977-60072;
# MGAAI:AREA=ICIZ02C,SAI=724-05-53977-60073;
# MGAAC:AREA=ICIZ02A,EA=77;
# MGAAC:AREA=ICIZ02B,EA=77;
# MGAAC:AREA=ICIZ02C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CORDEIROS | Change de LAC=30377 para LAC=50977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICWS01A;
# MGAAP:AREA=ICWS01B;
# MGAAP:AREA=ICWS01C;
# MGAAP:AREA=ICWS01M;
# MGAAP:AREA=ICWS01N;
# MGAAP:AREA=ICWS01O;
# MGRCP:AREA=ICWS01A;
# MGRCP:AREA=ICWS01B;
# MGRCP:AREA=ICWS01C;
# MGRCP:AREA=ICWS01M;
# MGRCP:AREA=ICWS01N;
# MGRCP:AREA=ICWS01O;
# MGAAE:AREA=ICWS01A;
# MGAAE:AREA=ICWS01B;
# MGAAE:AREA=ICWS01C;
# MGAAE:AREA=ICWS01M;
# MGAAE:AREA=ICWS01N;
# MGAAE:AREA=ICWS01O;
# MGAAI:AREA=ICWS01A,SAI=724-05-50977-60092;
# MGAAI:AREA=ICWS01B,SAI=724-05-50977-60093;
# MGAAI:AREA=ICWS01C,SAI=724-05-50977-60094;
# MGAAI:AREA=ICWS01M,SAI=724-05-50977-30066;
# MGAAI:AREA=ICWS01N,SAI=724-05-50977-30067;
# MGAAI:AREA=ICWS01O,SAI=724-05-50977-30068;
# MGAAC:AREA=ICWS01A,EA=77;
# MGAAC:AREA=ICWS01B,EA=77;
# MGAAC:AREA=ICWS01C,EA=77;
# MGAAC:AREA=ICWS01M,EA=77;
# MGAAC:AREA=ICWS01N,EA=77;
# MGAAC:AREA=ICWS01O,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CRAVOLÂNDIA | Change de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICVO01A;
# MGAAP:AREA=ICVO01B;
# MGAAP:AREA=ICVO01C;
# MGRCP:AREA=ICVO01A;
# MGRCP:AREA=ICVO01B;
# MGRCP:AREA=ICVO01C;
# MGAAE:AREA=ICVO01A;
# MGAAE:AREA=ICVO01B;
# MGAAE:AREA=ICVO01C;
# MGAAI:AREA=ICVO01A,SAI=724-05-50673-64807;
# MGAAI:AREA=ICVO01B,SAI=724-05-50673-64808;
# MGAAI:AREA=ICVO01C,SAI=724-05-50673-64809;
# MGAAC:AREA=ICVO01A,EA=73;
# MGAAC:AREA=ICVO01B,EA=73;
# MGAAC:AREA=ICVO01C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! GONGOGI | Change de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IGGG01A;
# MGAAP:AREA=IGGG01B;
# MGAAP:AREA=IGGG01C;
# MGRCP:AREA=IGGG01A;
# MGRCP:AREA=IGGG01B;
# MGRCP:AREA=IGGG01C;
# MGAAE:AREA=IGGG01A;
# MGAAE:AREA=IGGG01B;
# MGAAE:AREA=IGGG01C;
# MGAAI:AREA=IGGG01A,SAI=724-05-50673-60733;
# MGAAI:AREA=IGGG01B,SAI=724-05-50673-60734;
# MGAAI:AREA=IGGG01C,SAI=724-05-50673-60735;
# MGAAC:AREA=IGGG01A,EA=73;
# MGAAC:AREA=IGGG01B,EA=73;
# MGAAC:AREA=IGGG01C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! GUAJERU | Change de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IGEU02A;
# MGAAP:AREA=IGEU02B;
# MGAAP:AREA=IGEU02C;
# MGAAP:AREA=IGEU02M;
# MGAAP:AREA=IGEU02N;
# MGAAP:AREA=IGEU02O;
# MGRCP:AREA=IGEU02A;
# MGRCP:AREA=IGEU02B;
# MGRCP:AREA=IGEU02C;
# MGRCP:AREA=IGEU02M;
# MGRCP:AREA=IGEU02N;
# MGRCP:AREA=IGEU02O;
# MGAAE:AREA=IGEU02A;
# MGAAE:AREA=IGEU02B;
# MGAAE:AREA=IGEU02C;
# MGAAE:AREA=IGEU02M;
# MGAAE:AREA=IGEU02N;
# MGAAE:AREA=IGEU02O;
# MGAAI:AREA=IGEU02A,SAI=724-05-53977-60107;
# MGAAI:AREA=IGEU02B,SAI=724-05-53977-60108;
# MGAAI:AREA=IGEU02C,SAI=724-05-53977-60109;
# MGAAI:AREA=IGEU02M,SAI=724-05-53977-30078;
# MGAAI:AREA=IGEU02N,SAI=724-05-53977-30079;
# MGAAI:AREA=IGEU02O,SAI=724-05-53977-30080;
# MGAAC:AREA=IGEU02A,EA=77;
# MGAAC:AREA=IGEU02B,EA=77;
# MGAAC:AREA=IGEU02C,EA=77;
# MGAAC:AREA=IGEU02M,EA=77;
# MGAAC:AREA=IGEU02N,EA=77;
# MGAAC:AREA=IGEU02O,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! ICHU | Change de LAC=30975 para LAC=50375
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IICH015;
# MGAAP:AREA=IICH016;
# MGAAP:AREA=IICH017;
# MGAAP:AREA=IICH01A;
# MGAAP:AREA=IICH01B;
# MGAAP:AREA=IICH01C;
# MGRCP:AREA=IICH015;
# MGRCP:AREA=IICH016;
# MGRCP:AREA=IICH017;
# MGRCP:AREA=IICH01A;
# MGRCP:AREA=IICH01B;
# MGRCP:AREA=IICH01C;
# MGAAE:AREA=IICH015;
# MGAAE:AREA=IICH016;
# MGAAE:AREA=IICH017;
# MGAAE:AREA=IICH01A;
# MGAAE:AREA=IICH01B;
# MGAAE:AREA=IICH01C;
# MGAAI:AREA=IICH015,SAI=724-05-50375-64860;
# MGAAI:AREA=IICH016,SAI=724-05-50375-64861;
# MGAAI:AREA=IICH017,SAI=724-05-50375-64862;
# MGAAI:AREA=IICH01A,SAI=724-05-50375-60116;
# MGAAI:AREA=IICH01B,SAI=724-05-50375-60117;
# MGAAI:AREA=IICH01C,SAI=724-05-50375-60118;
# MGAAC:AREA=IICH015,EA=75;
# MGAAC:AREA=IICH016,EA=75;
# MGAAC:AREA=IICH017,EA=75;
# MGAAC:AREA=IICH01A,EA=75;
# MGAAC:AREA=IICH01B,EA=75;
# MGAAC:AREA=IICH01C,EA=75;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! ITAQUARA | Change de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IIQA02A;
# MGAAP:AREA=IIQA02B;
# MGAAP:AREA=IIQA02C;
# MGRCP:AREA=IIQA02A;
# MGRCP:AREA=IIQA02B;
# MGRCP:AREA=IIQA02C;
# MGAAE:AREA=IIQA02A;
# MGAAE:AREA=IIQA02B;
# MGAAE:AREA=IIQA02C;
# MGAAI:AREA=IIQA02A,SAI=724-05-50673-60475;
# MGAAI:AREA=IIQA02B,SAI=724-05-50673-60476;
# MGAAI:AREA=IIQA02C,SAI=724-05-50673-60477;
# MGAAC:AREA=IIQA02A,EA=73;
# MGAAC:AREA=IIQA02B,EA=73;
# MGAAC:AREA=IIQA02C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! JUSSARI | Change de LAC=30373 para LAC=50273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IJSI01A;
# MGAAP:AREA=IJSI01B;
# MGAAP:AREA=IJSI01C;
# MGAAP:AREA=IJSI01E;
# MGAAP:AREA=IJSI01F;
# MGAAP:AREA=IJSI01G;
# MGAAP:AREA=IJSI105;
# MGAAP:AREA=IJSI155;
# MGRCP:AREA=IJSI01A;
# MGRCP:AREA=IJSI01B;
# MGRCP:AREA=IJSI01C;
# MGRCP:AREA=IJSI01E;
# MGRCP:AREA=IJSI01F;
# MGRCP:AREA=IJSI01G;
# MGRCP:AREA=IJSI105;
# MGRCP:AREA=IJSI155;
# MGAAE:AREA=IJSI01A;
# MGAAE:AREA=IJSI01B;
# MGAAE:AREA=IJSI01C;
# MGAAE:AREA=IJSI01E;
# MGAAE:AREA=IJSI01F;
# MGAAE:AREA=IJSI01G;
# MGAAE:AREA=IJSI105;
# MGAAE:AREA=IJSI155;
# MGAAI:AREA=IJSI01A,SAI=724-05-50273-60158;
# MGAAI:AREA=IJSI01B,SAI=724-05-50273-60159;
# MGAAI:AREA=IJSI01C,SAI=724-05-50273-60160;
# MGAAI:AREA=IJSI01E,SAI=724-05-50273-60333;
# MGAAI:AREA=IJSI01F,SAI=724-05-50273-60334;
# MGAAI:AREA=IJSI01G,SAI=724-05-50273-60335;
# MGAAI:AREA=IJSI105,SAI=724-05-50273-60370;
# MGAAI:AREA=IJSI155,SAI=724-05-50273-60371;
# MGAAC:AREA=IJSI01A,EA=73;
# MGAAC:AREA=IJSI01B,EA=73;
# MGAAC:AREA=IJSI01C,EA=73;
# MGAAC:AREA=IJSI01E,EA=73;
# MGAAC:AREA=IJSI01F,EA=73;
# MGAAC:AREA=IJSI01G,EA=73;
# MGAAC:AREA=IJSI105,EA=73;
# MGAAC:AREA=IJSI155,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MAETINGA | Change de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMAY02A;
# MGAAP:AREA=IMAY02B;
# MGAAP:AREA=IMAY02C;
# MGAAP:AREA=IMAY02M;
# MGAAP:AREA=IMAY02N;
# MGAAP:AREA=IMAY02O;
# MGRCP:AREA=IMAY02A;
# MGRCP:AREA=IMAY02B;
# MGRCP:AREA=IMAY02C;
# MGRCP:AREA=IMAY02M;
# MGRCP:AREA=IMAY02N;
# MGRCP:AREA=IMAY02O;
# MGAAE:AREA=IMAY02A;
# MGAAE:AREA=IMAY02B;
# MGAAE:AREA=IMAY02C;
# MGAAE:AREA=IMAY02M;
# MGAAE:AREA=IMAY02N;
# MGAAE:AREA=IMAY02O;
# MGAAI:AREA=IMAY02A,SAI=724-05-53977-60182;
# MGAAI:AREA=IMAY02B,SAI=724-05-53977-60183;
# MGAAI:AREA=IMAY02C,SAI=724-05-53977-60184;
# MGAAI:AREA=IMAY02M,SAI=724-05-53977-30081;
# MGAAI:AREA=IMAY02N,SAI=724-05-53977-30082;
# MGAAI:AREA=IMAY02O,SAI=724-05-53977-30083;
# MGAAC:AREA=IMAY02A,EA=77;
# MGAAC:AREA=IMAY02B,EA=77;
# MGAAC:AREA=IMAY02C,EA=77;
# MGAAC:AREA=IMAY02M,EA=77;
# MGAAC:AREA=IMAY02N,EA=77;
# MGAAC:AREA=IMAY02O,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MALHADA DE PEDRAS | Change de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMDD01A;
# MGAAP:AREA=IMDD01B;
# MGAAP:AREA=IMDD01C;
# MGRCP:AREA=IMDD01A;
# MGRCP:AREA=IMDD01B;
# MGRCP:AREA=IMDD01C;
# MGAAE:AREA=IMDD01A;
# MGAAE:AREA=IMDD01B;
# MGAAE:AREA=IMDD01C;
# MGAAI:AREA=IMDD01A,SAI=724-05-53977-60191;
# MGAAI:AREA=IMDD01B,SAI=724-05-53977-60192;
# MGAAI:AREA=IMDD01C,SAI=724-05-53977-60193;
# MGAAC:AREA=IMDD01A,EA=77;
# MGAAC:AREA=IMDD01B,EA=77;
# MGAAC:AREA=IMDD01C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MIRANTE | Change de LAC=30377 para LAC=50977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMRQ01A;
# MGAAP:AREA=IMRQ01B;
# MGAAP:AREA=IMRQ01C;
# MGAAP:AREA=IMRQ151;
# MGAAP:AREA=IMRQ152;
# MGAAP:AREA=IMRQ153;
# MGAAP:AREA=IMRQ15A;
# MGAAP:AREA=IMRQ15B;
# MGAAP:AREA=IMRQ15C;
# MGRCP:AREA=IMRQ01A;
# MGRCP:AREA=IMRQ01B;
# MGRCP:AREA=IMRQ01C;
# MGRCP:AREA=IMRQ151;
# MGRCP:AREA=IMRQ152;
# MGRCP:AREA=IMRQ153;
# MGRCP:AREA=IMRQ15A;
# MGRCP:AREA=IMRQ15B;
# MGRCP:AREA=IMRQ15C;
# MGAAE:AREA=IMRQ01A;
# MGAAE:AREA=IMRQ01B;
# MGAAE:AREA=IMRQ01C;
# MGAAE:AREA=IMRQ151;
# MGAAE:AREA=IMRQ152;
# MGAAE:AREA=IMRQ153;
# MGAAE:AREA=IMRQ15A;
# MGAAE:AREA=IMRQ15B;
# MGAAE:AREA=IMRQ15C;
# MGAAI:AREA=IMRQ01A,SAI=724-05-50977-60200;
# MGAAI:AREA=IMRQ01B,SAI=724-05-50977-60201;
# MGAAI:AREA=IMRQ01C,SAI=724-05-50977-60202;
# MGAAI:AREA=IMRQ151,SAI=724-05-50977-30004;
# MGAAI:AREA=IMRQ152,SAI=724-05-50977-30005;
# MGAAI:AREA=IMRQ153,SAI=724-05-50977-30006;
# MGAAI:AREA=IMRQ15A,SAI=724-05-50977-30117;
# MGAAI:AREA=IMRQ15B,SAI=724-05-50977-30118;
# MGAAI:AREA=IMRQ15C,SAI=724-05-50977-30119;
# MGAAC:AREA=IMRQ01A,EA=77;
# MGAAC:AREA=IMRQ01B,EA=77;
# MGAAC:AREA=IMRQ01C,EA=77;
# MGAAC:AREA=IMRQ151,EA=77;
# MGAAC:AREA=IMRQ152,EA=77;
# MGAAC:AREA=IMRQ153,EA=77;
# MGAAC:AREA=IMRQ15A,EA=77;
# MGAAC:AREA=IMRQ15B,EA=77;
# MGAAC:AREA=IMRQ15C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MUNIZ FERREIRA | Change de LAC=30275 para LAC=51975
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMIZ01A;
# MGAAP:AREA=IMIZ01B;
# MGAAP:AREA=IMIZ01C;
# MGAAP:AREA=IMIZ01E;
# MGAAP:AREA=IMIZ01F;
# MGAAP:AREA=IMIZ01G;
# MGRCP:AREA=IMIZ01A;
# MGRCP:AREA=IMIZ01B;
# MGRCP:AREA=IMIZ01C;
# MGRCP:AREA=IMIZ01E;
# MGRCP:AREA=IMIZ01F;
# MGRCP:AREA=IMIZ01G;
# MGAAE:AREA=IMIZ01A;
# MGAAE:AREA=IMIZ01B;
# MGAAE:AREA=IMIZ01C;
# MGAAE:AREA=IMIZ01E;
# MGAAE:AREA=IMIZ01F;
# MGAAE:AREA=IMIZ01G;
# MGAAI:AREA=IMIZ01A,SAI=724-05-51975-60478;
# MGAAI:AREA=IMIZ01B,SAI=724-05-51975-60479;
# MGAAI:AREA=IMIZ01C,SAI=724-05-51975-60480;
# MGAAI:AREA=IMIZ01E,SAI=724-05-51975-60783;
# MGAAI:AREA=IMIZ01F,SAI=724-05-51975-60784;
# MGAAI:AREA=IMIZ01G,SAI=724-05-51975-60785;
# MGAAC:AREA=IMIZ01A,EA=75;
# MGAAC:AREA=IMIZ01B,EA=75;
# MGAAC:AREA=IMIZ01C,EA=75;
# MGAAC:AREA=IMIZ01E,EA=75;
# MGAAC:AREA=IMIZ01F,EA=75;
# MGAAC:AREA=IMIZ01G,EA=75;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SANTA CRUZ DA VITÓRIA | Change de LAC=30373 para LAC=50273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISVT01A;
# MGAAP:AREA=ISVT01B;
# MGAAP:AREA=ISVT01C;
# MGRCP:AREA=ISVT01A;
# MGRCP:AREA=ISVT01B;
# MGRCP:AREA=ISVT01C;
# MGAAE:AREA=ISVT01A;
# MGAAE:AREA=ISVT01B;
# MGAAE:AREA=ISVT01C;
# MGAAI:AREA=ISVT01A,SAI=724-05-50273-60272;
# MGAAI:AREA=ISVT01B,SAI=724-05-50273-60273;
# MGAAI:AREA=ISVT01C,SAI=724-05-50273-60274;
# MGAAC:AREA=ISVT01A,EA=73;
# MGAAC:AREA=ISVT01B,EA=73;
# MGAAC:AREA=ISVT01C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SANTA INÊS | Change de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISAT03A;
# MGAAP:AREA=ISAT03B;
# MGAAP:AREA=ISAT03C;
# MGAAP:AREA=ISAT03E;
# MGAAP:AREA=ISAT03F;
# MGAAP:AREA=ISAT03G;
# MGAAP:AREA=ISAT03N;
# MGAAP:AREA=ISAT03V;
# MGRCP:AREA=ISAT03A;
# MGRCP:AREA=ISAT03B;
# MGRCP:AREA=ISAT03C;
# MGRCP:AREA=ISAT03E;
# MGRCP:AREA=ISAT03F;
# MGRCP:AREA=ISAT03G;
# MGRCP:AREA=ISAT03N;
# MGRCP:AREA=ISAT03V;
# MGAAE:AREA=ISAT03A;
# MGAAE:AREA=ISAT03B;
# MGAAE:AREA=ISAT03C;
# MGAAE:AREA=ISAT03E;
# MGAAE:AREA=ISAT03F;
# MGAAE:AREA=ISAT03G;
# MGAAE:AREA=ISAT03N;
# MGAAE:AREA=ISAT03V;
# MGAAI:AREA=ISAT03A,SAI=724-05-50673-60739;
# MGAAI:AREA=ISAT03B,SAI=724-05-50673-60740;
# MGAAI:AREA=ISAT03C,SAI=724-05-50673-60741;
# MGAAI:AREA=ISAT03E,SAI=724-05-50673-61550;
# MGAAI:AREA=ISAT03F,SAI=724-05-50673-61551;
# MGAAI:AREA=ISAT03G,SAI=724-05-50673-61552;
# MGAAI:AREA=ISAT03N,SAI=724-05-50673-60043;
# MGAAI:AREA=ISAT03V,SAI=724-05-50673-60044;
# MGAAC:AREA=ISAT03A,EA=73;
# MGAAC:AREA=ISAT03B,EA=73;
# MGAAC:AREA=ISAT03C,EA=73;
# MGAAC:AREA=ISAT03E,EA=73;
# MGAAC:AREA=ISAT03F,EA=73;
# MGAAC:AREA=ISAT03G,EA=73;
# MGAAC:AREA=ISAT03N,EA=73;
# MGAAC:AREA=ISAT03V,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SÃO JOSÉ DA VITÓRIA | Change de LAC=30373 para LAC=50273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISVQ011;
# MGAAP:AREA=ISVQ012;
# MGAAP:AREA=ISVQ013;
# MGAAP:AREA=ISVQ01E;
# MGAAP:AREA=ISVQ01F;
# MGAAP:AREA=ISVQ01G;
# MGRCP:AREA=ISVQ011;
# MGRCP:AREA=ISVQ012;
# MGRCP:AREA=ISVQ013;
# MGRCP:AREA=ISVQ01E;
# MGRCP:AREA=ISVQ01F;
# MGRCP:AREA=ISVQ01G;
# MGAAE:AREA=ISVQ011;
# MGAAE:AREA=ISVQ012;
# MGAAE:AREA=ISVQ013;
# MGAAE:AREA=ISVQ01E;
# MGAAE:AREA=ISVQ01F;
# MGAAE:AREA=ISVQ01G;
# MGAAI:AREA=ISVQ011,SAI=724-05-50273-60269;
# MGAAI:AREA=ISVQ012,SAI=724-05-50273-60270;
# MGAAI:AREA=ISVQ013,SAI=724-05-50273-60271;
# MGAAI:AREA=ISVQ01E,SAI=724-05-50273-64785;
# MGAAI:AREA=ISVQ01F,SAI=724-05-50273-64786;
# MGAAI:AREA=ISVQ01G,SAI=724-05-50273-64787;
# MGAAC:AREA=ISVQ011,EA=73;
# MGAAC:AREA=ISVQ012,EA=73;
# MGAAC:AREA=ISVQ013,EA=73;
# MGAAC:AREA=ISVQ01E,EA=73;
# MGAAC:AREA=ISVQ01F,EA=73;
# MGAAC:AREA=ISVQ01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
# True

# %%
# Get 3G Ericsson's fallback commands
NOK_ERI_Toolkit.change_lai_3g_eri(my_df=df_eri_3g, my_cmd='fallback')
# Out:
# ! ARATACA | Fallback de LAC=30173 para LAC=51373
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IATW01A;
# MGAAP:AREA=IATW01B;
# MGAAP:AREA=IATW01C;
# MGAAP:AREA=IATW01E;
# MGAAP:AREA=IATW01F;
# MGAAP:AREA=IATW01G;
# MGRCP:AREA=IATW01A;
# MGRCP:AREA=IATW01B;
# MGRCP:AREA=IATW01C;
# MGRCP:AREA=IATW01E;
# MGRCP:AREA=IATW01F;
# MGRCP:AREA=IATW01G;
# MGAAE:AREA=IATW01A;
# MGAAE:AREA=IATW01B;
# MGAAE:AREA=IATW01C;
# MGAAE:AREA=IATW01E;
# MGAAE:AREA=IATW01F;
# MGAAE:AREA=IATW01G;
# MGAAI:AREA=IATW01A,SAI=724-05-30173-61050;
# MGAAI:AREA=IATW01B,SAI=724-05-30173-61051;
# MGAAI:AREA=IATW01C,SAI=724-05-30173-61052;
# MGAAI:AREA=IATW01E,SAI=724-05-30173-64650;
# MGAAI:AREA=IATW01F,SAI=724-05-30173-64651;
# MGAAI:AREA=IATW01G,SAI=724-05-30173-64652;
# MGAAC:AREA=IATW01A,EA=73;
# MGAAC:AREA=IATW01B,EA=73;
# MGAAC:AREA=IATW01C,EA=73;
# MGAAC:AREA=IATW01E,EA=73;
# MGAAC:AREA=IATW01F,EA=73;
# MGAAC:AREA=IATW01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! FLORESTA AZUL | Fallback de LAC=30173 para LAC=51173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IFAL01A;
# MGAAP:AREA=IFAL01B;
# MGAAP:AREA=IFAL01C;
# MGAAP:AREA=IFAL01E;
# MGAAP:AREA=IFAL01F;
# MGAAP:AREA=IFAL01G;
# MGRCP:AREA=IFAL01A;
# MGRCP:AREA=IFAL01B;
# MGRCP:AREA=IFAL01C;
# MGRCP:AREA=IFAL01E;
# MGRCP:AREA=IFAL01F;
# MGRCP:AREA=IFAL01G;
# MGAAE:AREA=IFAL01A;
# MGAAE:AREA=IFAL01B;
# MGAAE:AREA=IFAL01C;
# MGAAE:AREA=IFAL01E;
# MGAAE:AREA=IFAL01F;
# MGAAE:AREA=IFAL01G;
# MGAAI:AREA=IFAL01A,SAI=724-05-30173-60470;
# MGAAI:AREA=IFAL01B,SAI=724-05-30173-60471;
# MGAAI:AREA=IFAL01C,SAI=724-05-30173-60472;
# MGAAI:AREA=IFAL01E,SAI=724-05-30173-64653;
# MGAAI:AREA=IFAL01F,SAI=724-05-30173-64654;
# MGAAI:AREA=IFAL01G,SAI=724-05-30173-64655;
# MGAAC:AREA=IFAL01A,EA=73;
# MGAAC:AREA=IFAL01B,EA=73;
# MGAAC:AREA=IFAL01C,EA=73;
# MGAAC:AREA=IFAL01E,EA=73;
# MGAAC:AREA=IFAL01F,EA=73;
# MGAAC:AREA=IFAL01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! ITAPÉ | Fallback de LAC=30173 para LAC=51173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IYPE03A;
# MGAAP:AREA=IYPE03B;
# MGAAP:AREA=IYPE03C;
# MGRCP:AREA=IYPE03A;
# MGRCP:AREA=IYPE03B;
# MGRCP:AREA=IYPE03C;
# MGAAE:AREA=IYPE03A;
# MGAAE:AREA=IYPE03B;
# MGAAE:AREA=IYPE03C;
# MGAAI:AREA=IYPE03A,SAI=724-05-30173-61056;
# MGAAI:AREA=IYPE03B,SAI=724-05-30173-61057;
# MGAAI:AREA=IYPE03C,SAI=724-05-30173-61058;
# MGAAC:AREA=IYPE03A,EA=73;
# MGAAC:AREA=IYPE03B,EA=73;
# MGAAC:AREA=IYPE03C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! PAU BRASIL | Fallback de LAC=30173 para LAC=51173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IPSL01A;
# MGAAP:AREA=IPSL01B;
# MGAAP:AREA=IPSL01C;
# MGAAP:AREA=IPSL01E;
# MGAAP:AREA=IPSL01F;
# MGAAP:AREA=IPSL01G;
# MGRCP:AREA=IPSL01A;
# MGRCP:AREA=IPSL01B;
# MGRCP:AREA=IPSL01C;
# MGRCP:AREA=IPSL01E;
# MGRCP:AREA=IPSL01F;
# MGRCP:AREA=IPSL01G;
# MGAAE:AREA=IPSL01A;
# MGAAE:AREA=IPSL01B;
# MGAAE:AREA=IPSL01C;
# MGAAE:AREA=IPSL01E;
# MGAAE:AREA=IPSL01F;
# MGAAE:AREA=IPSL01G;
# MGAAI:AREA=IPSL01A,SAI=724-05-30173-30307;
# MGAAI:AREA=IPSL01B,SAI=724-05-30173-31307;
# MGAAI:AREA=IPSL01C,SAI=724-05-30173-32307;
# MGAAI:AREA=IPSL01E,SAI=724-05-30173-64656;
# MGAAI:AREA=IPSL01F,SAI=724-05-30173-64657;
# MGAAI:AREA=IPSL01G,SAI=724-05-30173-64658;
# MGAAC:AREA=IPSL01A,EA=73;
# MGAAC:AREA=IPSL01B,EA=73;
# MGAAC:AREA=IPSL01C,EA=73;
# MGAAC:AREA=IPSL01E,EA=73;
# MGAAC:AREA=IPSL01F,EA=73;
# MGAAC:AREA=IPSL01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! BARRA DO ROCHA | Fallback de LAC=30273 para LAC=51273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IBHO01A;
# MGAAP:AREA=IBHO01B;
# MGAAP:AREA=IBHO01C;
# MGAAP:AREA=IBHO01E;
# MGAAP:AREA=IBHO01F;
# MGAAP:AREA=IBHO01G;
# MGRCP:AREA=IBHO01A;
# MGRCP:AREA=IBHO01B;
# MGRCP:AREA=IBHO01C;
# MGRCP:AREA=IBHO01E;
# MGRCP:AREA=IBHO01F;
# MGRCP:AREA=IBHO01G;
# MGAAE:AREA=IBHO01A;
# MGAAE:AREA=IBHO01B;
# MGAAE:AREA=IBHO01C;
# MGAAE:AREA=IBHO01E;
# MGAAE:AREA=IBHO01F;
# MGAAE:AREA=IBHO01G;
# MGAAI:AREA=IBHO01A,SAI=724-05-30273-60730;
# MGAAI:AREA=IBHO01B,SAI=724-05-30273-60731;
# MGAAI:AREA=IBHO01C,SAI=724-05-30273-60732;
# MGAAI:AREA=IBHO01E,SAI=724-05-30273-33677;
# MGAAI:AREA=IBHO01F,SAI=724-05-30273-33678;
# MGAAI:AREA=IBHO01G,SAI=724-05-30273-33679;
# MGAAC:AREA=IBHO01A,EA=73;
# MGAAC:AREA=IBHO01B,EA=73;
# MGAAC:AREA=IBHO01C,EA=73;
# MGAAC:AREA=IBHO01E,EA=73;
# MGAAC:AREA=IBHO01F,EA=73;
# MGAAC:AREA=IBHO01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! BOM JESUS DA SERRA | Fallback de LAC=30377 para LAC=53377
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IBJD03A;
# MGAAP:AREA=IBJD03B;
# MGAAP:AREA=IBJD03C;
# MGRCP:AREA=IBJD03A;
# MGRCP:AREA=IBJD03B;
# MGRCP:AREA=IBJD03C;
# MGAAE:AREA=IBJD03A;
# MGAAE:AREA=IBJD03B;
# MGAAE:AREA=IBJD03C;
# MGAAI:AREA=IBJD03A,SAI=724-05-30377-60038;
# MGAAI:AREA=IBJD03B,SAI=724-05-30377-60039;
# MGAAI:AREA=IBJD03C,SAI=724-05-30377-60040;
# MGAAC:AREA=IBJD03A,EA=77;
# MGAAC:AREA=IBJD03B,EA=77;
# MGAAC:AREA=IBJD03C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CAFARNAUM | Fallback de LAC=31074 para LAC=51374
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICFM01A;
# MGAAP:AREA=ICFM01B;
# MGAAP:AREA=ICFM01C;
# MGAAP:AREA=ICFM01M;
# MGAAP:AREA=ICFM01N;
# MGAAP:AREA=ICFM01O;
# MGRCP:AREA=ICFM01A;
# MGRCP:AREA=ICFM01B;
# MGRCP:AREA=ICFM01C;
# MGRCP:AREA=ICFM01M;
# MGRCP:AREA=ICFM01N;
# MGRCP:AREA=ICFM01O;
# MGAAE:AREA=ICFM01A;
# MGAAE:AREA=ICFM01B;
# MGAAE:AREA=ICFM01C;
# MGAAE:AREA=ICFM01M;
# MGAAE:AREA=ICFM01N;
# MGAAE:AREA=ICFM01O;
# MGAAI:AREA=ICFM01A,SAI=724-05-31074-60068;
# MGAAI:AREA=ICFM01B,SAI=724-05-31074-60069;
# MGAAI:AREA=ICFM01C,SAI=724-05-31074-60070;
# MGAAI:AREA=ICFM01M,SAI=724-05-31074-30075;
# MGAAI:AREA=ICFM01N,SAI=724-05-31074-30076;
# MGAAI:AREA=ICFM01O,SAI=724-05-31074-30077;
# MGAAC:AREA=ICFM01A,EA=74;
# MGAAC:AREA=ICFM01B,EA=74;
# MGAAC:AREA=ICFM01C,EA=74;
# MGAAC:AREA=ICFM01M,EA=74;
# MGAAC:AREA=ICFM01N,EA=74;
# MGAAC:AREA=ICFM01O,EA=74;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CARAÍBAS | Fallback de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICIZ02A;
# MGAAP:AREA=ICIZ02B;
# MGAAP:AREA=ICIZ02C;
# MGRCP:AREA=ICIZ02A;
# MGRCP:AREA=ICIZ02B;
# MGRCP:AREA=ICIZ02C;
# MGAAE:AREA=ICIZ02A;
# MGAAE:AREA=ICIZ02B;
# MGAAE:AREA=ICIZ02C;
# MGAAI:AREA=ICIZ02A,SAI=724-05-30377-60071;
# MGAAI:AREA=ICIZ02B,SAI=724-05-30377-60072;
# MGAAI:AREA=ICIZ02C,SAI=724-05-30377-60073;
# MGAAC:AREA=ICIZ02A,EA=77;
# MGAAC:AREA=ICIZ02B,EA=77;
# MGAAC:AREA=ICIZ02C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CORDEIROS | Fallback de LAC=30377 para LAC=50977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICWS01A;
# MGAAP:AREA=ICWS01B;
# MGAAP:AREA=ICWS01C;
# MGAAP:AREA=ICWS01M;
# MGAAP:AREA=ICWS01N;
# MGAAP:AREA=ICWS01O;
# MGRCP:AREA=ICWS01A;
# MGRCP:AREA=ICWS01B;
# MGRCP:AREA=ICWS01C;
# MGRCP:AREA=ICWS01M;
# MGRCP:AREA=ICWS01N;
# MGRCP:AREA=ICWS01O;
# MGAAE:AREA=ICWS01A;
# MGAAE:AREA=ICWS01B;
# MGAAE:AREA=ICWS01C;
# MGAAE:AREA=ICWS01M;
# MGAAE:AREA=ICWS01N;
# MGAAE:AREA=ICWS01O;
# MGAAI:AREA=ICWS01A,SAI=724-05-30377-60092;
# MGAAI:AREA=ICWS01B,SAI=724-05-30377-60093;
# MGAAI:AREA=ICWS01C,SAI=724-05-30377-60094;
# MGAAI:AREA=ICWS01M,SAI=724-05-30377-30066;
# MGAAI:AREA=ICWS01N,SAI=724-05-30377-30067;
# MGAAI:AREA=ICWS01O,SAI=724-05-30377-30068;
# MGAAC:AREA=ICWS01A,EA=77;
# MGAAC:AREA=ICWS01B,EA=77;
# MGAAC:AREA=ICWS01C,EA=77;
# MGAAC:AREA=ICWS01M,EA=77;
# MGAAC:AREA=ICWS01N,EA=77;
# MGAAC:AREA=ICWS01O,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CRAVOLÂNDIA | Fallback de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ICVO01A;
# MGAAP:AREA=ICVO01B;
# MGAAP:AREA=ICVO01C;
# MGRCP:AREA=ICVO01A;
# MGRCP:AREA=ICVO01B;
# MGRCP:AREA=ICVO01C;
# MGAAE:AREA=ICVO01A;
# MGAAE:AREA=ICVO01B;
# MGAAE:AREA=ICVO01C;
# MGAAI:AREA=ICVO01A,SAI=724-05-30273-64807;
# MGAAI:AREA=ICVO01B,SAI=724-05-30273-64808;
# MGAAI:AREA=ICVO01C,SAI=724-05-30273-64809;
# MGAAC:AREA=ICVO01A,EA=73;
# MGAAC:AREA=ICVO01B,EA=73;
# MGAAC:AREA=ICVO01C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! GONGOGI | Fallback de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IGGG01A;
# MGAAP:AREA=IGGG01B;
# MGAAP:AREA=IGGG01C;
# MGRCP:AREA=IGGG01A;
# MGRCP:AREA=IGGG01B;
# MGRCP:AREA=IGGG01C;
# MGAAE:AREA=IGGG01A;
# MGAAE:AREA=IGGG01B;
# MGAAE:AREA=IGGG01C;
# MGAAI:AREA=IGGG01A,SAI=724-05-30273-60733;
# MGAAI:AREA=IGGG01B,SAI=724-05-30273-60734;
# MGAAI:AREA=IGGG01C,SAI=724-05-30273-60735;
# MGAAC:AREA=IGGG01A,EA=73;
# MGAAC:AREA=IGGG01B,EA=73;
# MGAAC:AREA=IGGG01C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! GUAJERU | Fallback de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IGEU02A;
# MGAAP:AREA=IGEU02B;
# MGAAP:AREA=IGEU02C;
# MGAAP:AREA=IGEU02M;
# MGAAP:AREA=IGEU02N;
# MGAAP:AREA=IGEU02O;
# MGRCP:AREA=IGEU02A;
# MGRCP:AREA=IGEU02B;
# MGRCP:AREA=IGEU02C;
# MGRCP:AREA=IGEU02M;
# MGRCP:AREA=IGEU02N;
# MGRCP:AREA=IGEU02O;
# MGAAE:AREA=IGEU02A;
# MGAAE:AREA=IGEU02B;
# MGAAE:AREA=IGEU02C;
# MGAAE:AREA=IGEU02M;
# MGAAE:AREA=IGEU02N;
# MGAAE:AREA=IGEU02O;
# MGAAI:AREA=IGEU02A,SAI=724-05-30377-60107;
# MGAAI:AREA=IGEU02B,SAI=724-05-30377-60108;
# MGAAI:AREA=IGEU02C,SAI=724-05-30377-60109;
# MGAAI:AREA=IGEU02M,SAI=724-05-30377-30078;
# MGAAI:AREA=IGEU02N,SAI=724-05-30377-30079;
# MGAAI:AREA=IGEU02O,SAI=724-05-30377-30080;
# MGAAC:AREA=IGEU02A,EA=77;
# MGAAC:AREA=IGEU02B,EA=77;
# MGAAC:AREA=IGEU02C,EA=77;
# MGAAC:AREA=IGEU02M,EA=77;
# MGAAC:AREA=IGEU02N,EA=77;
# MGAAC:AREA=IGEU02O,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! ICHU | Fallback de LAC=30975 para LAC=50375
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IICH015;
# MGAAP:AREA=IICH016;
# MGAAP:AREA=IICH017;
# MGAAP:AREA=IICH01A;
# MGAAP:AREA=IICH01B;
# MGAAP:AREA=IICH01C;
# MGRCP:AREA=IICH015;
# MGRCP:AREA=IICH016;
# MGRCP:AREA=IICH017;
# MGRCP:AREA=IICH01A;
# MGRCP:AREA=IICH01B;
# MGRCP:AREA=IICH01C;
# MGAAE:AREA=IICH015;
# MGAAE:AREA=IICH016;
# MGAAE:AREA=IICH017;
# MGAAE:AREA=IICH01A;
# MGAAE:AREA=IICH01B;
# MGAAE:AREA=IICH01C;
# MGAAI:AREA=IICH015,SAI=724-05-30975-64860;
# MGAAI:AREA=IICH016,SAI=724-05-30975-64861;
# MGAAI:AREA=IICH017,SAI=724-05-30975-64862;
# MGAAI:AREA=IICH01A,SAI=724-05-30975-60116;
# MGAAI:AREA=IICH01B,SAI=724-05-30975-60117;
# MGAAI:AREA=IICH01C,SAI=724-05-30975-60118;
# MGAAC:AREA=IICH015,EA=75;
# MGAAC:AREA=IICH016,EA=75;
# MGAAC:AREA=IICH017,EA=75;
# MGAAC:AREA=IICH01A,EA=75;
# MGAAC:AREA=IICH01B,EA=75;
# MGAAC:AREA=IICH01C,EA=75;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! ITAQUARA | Fallback de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IIQA02A;
# MGAAP:AREA=IIQA02B;
# MGAAP:AREA=IIQA02C;
# MGRCP:AREA=IIQA02A;
# MGRCP:AREA=IIQA02B;
# MGRCP:AREA=IIQA02C;
# MGAAE:AREA=IIQA02A;
# MGAAE:AREA=IIQA02B;
# MGAAE:AREA=IIQA02C;
# MGAAI:AREA=IIQA02A,SAI=724-05-30273-60475;
# MGAAI:AREA=IIQA02B,SAI=724-05-30273-60476;
# MGAAI:AREA=IIQA02C,SAI=724-05-30273-60477;
# MGAAC:AREA=IIQA02A,EA=73;
# MGAAC:AREA=IIQA02B,EA=73;
# MGAAC:AREA=IIQA02C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! JUSSARI | Fallback de LAC=30373 para LAC=50273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IJSI01A;
# MGAAP:AREA=IJSI01B;
# MGAAP:AREA=IJSI01C;
# MGAAP:AREA=IJSI01E;
# MGAAP:AREA=IJSI01F;
# MGAAP:AREA=IJSI01G;
# MGAAP:AREA=IJSI105;
# MGAAP:AREA=IJSI155;
# MGRCP:AREA=IJSI01A;
# MGRCP:AREA=IJSI01B;
# MGRCP:AREA=IJSI01C;
# MGRCP:AREA=IJSI01E;
# MGRCP:AREA=IJSI01F;
# MGRCP:AREA=IJSI01G;
# MGRCP:AREA=IJSI105;
# MGRCP:AREA=IJSI155;
# MGAAE:AREA=IJSI01A;
# MGAAE:AREA=IJSI01B;
# MGAAE:AREA=IJSI01C;
# MGAAE:AREA=IJSI01E;
# MGAAE:AREA=IJSI01F;
# MGAAE:AREA=IJSI01G;
# MGAAE:AREA=IJSI105;
# MGAAE:AREA=IJSI155;
# MGAAI:AREA=IJSI01A,SAI=724-05-30373-60158;
# MGAAI:AREA=IJSI01B,SAI=724-05-30373-60159;
# MGAAI:AREA=IJSI01C,SAI=724-05-30373-60160;
# MGAAI:AREA=IJSI01E,SAI=724-05-30373-60333;
# MGAAI:AREA=IJSI01F,SAI=724-05-30373-60334;
# MGAAI:AREA=IJSI01G,SAI=724-05-30373-60335;
# MGAAI:AREA=IJSI105,SAI=724-05-30373-60370;
# MGAAI:AREA=IJSI155,SAI=724-05-30373-60371;
# MGAAC:AREA=IJSI01A,EA=73;
# MGAAC:AREA=IJSI01B,EA=73;
# MGAAC:AREA=IJSI01C,EA=73;
# MGAAC:AREA=IJSI01E,EA=73;
# MGAAC:AREA=IJSI01F,EA=73;
# MGAAC:AREA=IJSI01G,EA=73;
# MGAAC:AREA=IJSI105,EA=73;
# MGAAC:AREA=IJSI155,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MAETINGA | Fallback de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMAY02A;
# MGAAP:AREA=IMAY02B;
# MGAAP:AREA=IMAY02C;
# MGAAP:AREA=IMAY02M;
# MGAAP:AREA=IMAY02N;
# MGAAP:AREA=IMAY02O;
# MGRCP:AREA=IMAY02A;
# MGRCP:AREA=IMAY02B;
# MGRCP:AREA=IMAY02C;
# MGRCP:AREA=IMAY02M;
# MGRCP:AREA=IMAY02N;
# MGRCP:AREA=IMAY02O;
# MGAAE:AREA=IMAY02A;
# MGAAE:AREA=IMAY02B;
# MGAAE:AREA=IMAY02C;
# MGAAE:AREA=IMAY02M;
# MGAAE:AREA=IMAY02N;
# MGAAE:AREA=IMAY02O;
# MGAAI:AREA=IMAY02A,SAI=724-05-30377-60182;
# MGAAI:AREA=IMAY02B,SAI=724-05-30377-60183;
# MGAAI:AREA=IMAY02C,SAI=724-05-30377-60184;
# MGAAI:AREA=IMAY02M,SAI=724-05-30377-30081;
# MGAAI:AREA=IMAY02N,SAI=724-05-30377-30082;
# MGAAI:AREA=IMAY02O,SAI=724-05-30377-30083;
# MGAAC:AREA=IMAY02A,EA=77;
# MGAAC:AREA=IMAY02B,EA=77;
# MGAAC:AREA=IMAY02C,EA=77;
# MGAAC:AREA=IMAY02M,EA=77;
# MGAAC:AREA=IMAY02N,EA=77;
# MGAAC:AREA=IMAY02O,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MALHADA DE PEDRAS | Fallback de LAC=30377 para LAC=53977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMDD01A;
# MGAAP:AREA=IMDD01B;
# MGAAP:AREA=IMDD01C;
# MGRCP:AREA=IMDD01A;
# MGRCP:AREA=IMDD01B;
# MGRCP:AREA=IMDD01C;
# MGAAE:AREA=IMDD01A;
# MGAAE:AREA=IMDD01B;
# MGAAE:AREA=IMDD01C;
# MGAAI:AREA=IMDD01A,SAI=724-05-30377-60191;
# MGAAI:AREA=IMDD01B,SAI=724-05-30377-60192;
# MGAAI:AREA=IMDD01C,SAI=724-05-30377-60193;
# MGAAC:AREA=IMDD01A,EA=77;
# MGAAC:AREA=IMDD01B,EA=77;
# MGAAC:AREA=IMDD01C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MIRANTE | Fallback de LAC=30377 para LAC=50977
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMRQ01A;
# MGAAP:AREA=IMRQ01B;
# MGAAP:AREA=IMRQ01C;
# MGAAP:AREA=IMRQ151;
# MGAAP:AREA=IMRQ152;
# MGAAP:AREA=IMRQ153;
# MGAAP:AREA=IMRQ15A;
# MGAAP:AREA=IMRQ15B;
# MGAAP:AREA=IMRQ15C;
# MGRCP:AREA=IMRQ01A;
# MGRCP:AREA=IMRQ01B;
# MGRCP:AREA=IMRQ01C;
# MGRCP:AREA=IMRQ151;
# MGRCP:AREA=IMRQ152;
# MGRCP:AREA=IMRQ153;
# MGRCP:AREA=IMRQ15A;
# MGRCP:AREA=IMRQ15B;
# MGRCP:AREA=IMRQ15C;
# MGAAE:AREA=IMRQ01A;
# MGAAE:AREA=IMRQ01B;
# MGAAE:AREA=IMRQ01C;
# MGAAE:AREA=IMRQ151;
# MGAAE:AREA=IMRQ152;
# MGAAE:AREA=IMRQ153;
# MGAAE:AREA=IMRQ15A;
# MGAAE:AREA=IMRQ15B;
# MGAAE:AREA=IMRQ15C;
# MGAAI:AREA=IMRQ01A,SAI=724-05-30377-60200;
# MGAAI:AREA=IMRQ01B,SAI=724-05-30377-60201;
# MGAAI:AREA=IMRQ01C,SAI=724-05-30377-60202;
# MGAAI:AREA=IMRQ151,SAI=724-05-30377-30004;
# MGAAI:AREA=IMRQ152,SAI=724-05-30377-30005;
# MGAAI:AREA=IMRQ153,SAI=724-05-30377-30006;
# MGAAI:AREA=IMRQ15A,SAI=724-05-30377-30117;
# MGAAI:AREA=IMRQ15B,SAI=724-05-30377-30118;
# MGAAI:AREA=IMRQ15C,SAI=724-05-30377-30119;
# MGAAC:AREA=IMRQ01A,EA=77;
# MGAAC:AREA=IMRQ01B,EA=77;
# MGAAC:AREA=IMRQ01C,EA=77;
# MGAAC:AREA=IMRQ151,EA=77;
# MGAAC:AREA=IMRQ152,EA=77;
# MGAAC:AREA=IMRQ153,EA=77;
# MGAAC:AREA=IMRQ15A,EA=77;
# MGAAC:AREA=IMRQ15B,EA=77;
# MGAAC:AREA=IMRQ15C,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! MUNIZ FERREIRA | Fallback de LAC=30275 para LAC=51975
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IMIZ01A;
# MGAAP:AREA=IMIZ01B;
# MGAAP:AREA=IMIZ01C;
# MGAAP:AREA=IMIZ01E;
# MGAAP:AREA=IMIZ01F;
# MGAAP:AREA=IMIZ01G;
# MGRCP:AREA=IMIZ01A;
# MGRCP:AREA=IMIZ01B;
# MGRCP:AREA=IMIZ01C;
# MGRCP:AREA=IMIZ01E;
# MGRCP:AREA=IMIZ01F;
# MGRCP:AREA=IMIZ01G;
# MGAAE:AREA=IMIZ01A;
# MGAAE:AREA=IMIZ01B;
# MGAAE:AREA=IMIZ01C;
# MGAAE:AREA=IMIZ01E;
# MGAAE:AREA=IMIZ01F;
# MGAAE:AREA=IMIZ01G;
# MGAAI:AREA=IMIZ01A,SAI=724-05-30275-60478;
# MGAAI:AREA=IMIZ01B,SAI=724-05-30275-60479;
# MGAAI:AREA=IMIZ01C,SAI=724-05-30275-60480;
# MGAAI:AREA=IMIZ01E,SAI=724-05-30275-60783;
# MGAAI:AREA=IMIZ01F,SAI=724-05-30275-60784;
# MGAAI:AREA=IMIZ01G,SAI=724-05-30275-60785;
# MGAAC:AREA=IMIZ01A,EA=75;
# MGAAC:AREA=IMIZ01B,EA=75;
# MGAAC:AREA=IMIZ01C,EA=75;
# MGAAC:AREA=IMIZ01E,EA=75;
# MGAAC:AREA=IMIZ01F,EA=75;
# MGAAC:AREA=IMIZ01G,EA=75;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SANTA CRUZ DA VITÓRIA | Fallback de LAC=30373 para LAC=50273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISVT01A;
# MGAAP:AREA=ISVT01B;
# MGAAP:AREA=ISVT01C;
# MGRCP:AREA=ISVT01A;
# MGRCP:AREA=ISVT01B;
# MGRCP:AREA=ISVT01C;
# MGAAE:AREA=ISVT01A;
# MGAAE:AREA=ISVT01B;
# MGAAE:AREA=ISVT01C;
# MGAAI:AREA=ISVT01A,SAI=724-05-30373-60272;
# MGAAI:AREA=ISVT01B,SAI=724-05-30373-60273;
# MGAAI:AREA=ISVT01C,SAI=724-05-30373-60274;
# MGAAC:AREA=ISVT01A,EA=73;
# MGAAC:AREA=ISVT01B,EA=73;
# MGAAC:AREA=ISVT01C,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SANTA INÊS | Fallback de LAC=30273 para LAC=50673
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISAT03A;
# MGAAP:AREA=ISAT03B;
# MGAAP:AREA=ISAT03C;
# MGAAP:AREA=ISAT03E;
# MGAAP:AREA=ISAT03F;
# MGAAP:AREA=ISAT03G;
# MGAAP:AREA=ISAT03N;
# MGAAP:AREA=ISAT03V;
# MGRCP:AREA=ISAT03A;
# MGRCP:AREA=ISAT03B;
# MGRCP:AREA=ISAT03C;
# MGRCP:AREA=ISAT03E;
# MGRCP:AREA=ISAT03F;
# MGRCP:AREA=ISAT03G;
# MGRCP:AREA=ISAT03N;
# MGRCP:AREA=ISAT03V;
# MGAAE:AREA=ISAT03A;
# MGAAE:AREA=ISAT03B;
# MGAAE:AREA=ISAT03C;
# MGAAE:AREA=ISAT03E;
# MGAAE:AREA=ISAT03F;
# MGAAE:AREA=ISAT03G;
# MGAAE:AREA=ISAT03N;
# MGAAE:AREA=ISAT03V;
# MGAAI:AREA=ISAT03A,SAI=724-05-30273-60739;
# MGAAI:AREA=ISAT03B,SAI=724-05-30273-60740;
# MGAAI:AREA=ISAT03C,SAI=724-05-30273-60741;
# MGAAI:AREA=ISAT03E,SAI=724-05-30273-61550;
# MGAAI:AREA=ISAT03F,SAI=724-05-30273-61551;
# MGAAI:AREA=ISAT03G,SAI=724-05-30273-61552;
# MGAAI:AREA=ISAT03N,SAI=724-05-30273-60043;
# MGAAI:AREA=ISAT03V,SAI=724-05-30273-60044;
# MGAAC:AREA=ISAT03A,EA=73;
# MGAAC:AREA=ISAT03B,EA=73;
# MGAAC:AREA=ISAT03C,EA=73;
# MGAAC:AREA=ISAT03E,EA=73;
# MGAAC:AREA=ISAT03F,EA=73;
# MGAAC:AREA=ISAT03G,EA=73;
# MGAAC:AREA=ISAT03N,EA=73;
# MGAAC:AREA=ISAT03V,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SÃO JOSÉ DA VITÓRIA | Fallback de LAC=30373 para LAC=50273
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISVQ011;
# MGAAP:AREA=ISVQ012;
# MGAAP:AREA=ISVQ013;
# MGAAP:AREA=ISVQ01E;
# MGAAP:AREA=ISVQ01F;
# MGAAP:AREA=ISVQ01G;
# MGRCP:AREA=ISVQ011;
# MGRCP:AREA=ISVQ012;
# MGRCP:AREA=ISVQ013;
# MGRCP:AREA=ISVQ01E;
# MGRCP:AREA=ISVQ01F;
# MGRCP:AREA=ISVQ01G;
# MGAAE:AREA=ISVQ011;
# MGAAE:AREA=ISVQ012;
# MGAAE:AREA=ISVQ013;
# MGAAE:AREA=ISVQ01E;
# MGAAE:AREA=ISVQ01F;
# MGAAE:AREA=ISVQ01G;
# MGAAI:AREA=ISVQ011,SAI=724-05-30373-60269;
# MGAAI:AREA=ISVQ012,SAI=724-05-30373-60270;
# MGAAI:AREA=ISVQ013,SAI=724-05-30373-60271;
# MGAAI:AREA=ISVQ01E,SAI=724-05-30373-64785;
# MGAAI:AREA=ISVQ01F,SAI=724-05-30373-64786;
# MGAAI:AREA=ISVQ01G,SAI=724-05-30373-64787;
# MGAAC:AREA=ISVQ011,EA=73;
# MGAAC:AREA=ISVQ012,EA=73;
# MGAAC:AREA=ISVQ013,EA=73;
# MGAAC:AREA=ISVQ01E,EA=73;
# MGAAC:AREA=ISVQ01F,EA=73;
# MGAAC:AREA=ISVQ01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
# True
