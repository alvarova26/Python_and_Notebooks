# %% [markdown]
# # ALL LACs of ALL MSSs

# %% [markdown]
# ## Import Modules

# %%
# Import modules (NOK_Toolkit) & others that will be needed along the program
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import NOK_Toolkit as NOK_Toolkit

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Main Program

# %% [markdown]
# ### Initialize variables

# %%
# Initialize variables used in the program 
MSS_Name = '0'
MSS_Date = '0'
MSS_Time = '0'
LAC_MCC = '0'
LAC_MNC = '0'
LAC_NO = '0'
LAC_NAME = '0'
LAC_AT = '0'
LAC_REPAG_INT = '0'
LAC_RNGP = '0'
LAC_MNC_AL = '0'
LAC_DSAV = '0'
LAC_TZ = '0'
LAC_HONLA = '0'

MSS_Pars = [MSS_Name, MSS_Date, MSS_Time]
LAC_Pars = [LAC_MCC, LAC_MNC, LAC_NO, LAC_NAME, LAC_AT, LAC_REPAG_INT, LAC_RNGP, LAC_MNC_AL, LAC_DSAV, LAC_TZ, LAC_HONLA]

index = 0
position = 0
LAC_count = 0

# %%
# Create & Initialize & Set the pd.DataFrame
col_names = ['MSS','Date','Time','MCC','MNC','LAC_str','LAC_NAME','AT','INT','RNGP','MNC_AL','DSAV','TZ','HONLA']
df_MSS_LACs = pd.DataFrame(columns=col_names)
df_MSS_LACs.loc[0] = [MSS_Name, MSS_Date, MSS_Time, LAC_MCC, LAC_MNC, LAC_NO, LAC_NAME, LAC_AT, LAC_REPAG_INT, LAC_RNGP, LAC_MNC_AL, LAC_DSAV, LAC_TZ, LAC_HONLA]

# %%
# Especify the path of the log file
path_to_file = 'C:/Users/Alvaro/OneDrive/My Files/_Scripts_Models/Commands Generators Logs/20220204 - ZELO - All_MSS.txt'

# %% [markdown]
# ### Load log file

# %%
# Load the log file
log_file = NOK_Toolkit.open_file(path_to_file)

# %% [markdown]
# ### Execute & Create pd.DataFrame & Pring (Main Function)

# %%
# Run the main program (txt => pd.DataFrame)
while (index < len(log_file)-1):
    index, position, MSS_Pars = NOK_Toolkit.get_mss_pars(log_file, index,'ZELO;')
    while (index < len(log_file)-1) and (not position == 999):
        index, position, LAC_Pars = NOK_Toolkit.get_zelo_lac_pars(log_file,index)
        if position == 999:                                         # if 'COMMAND EXECUTED'
            index = index + 1                                       # Increase index to read next line
        else:
            new_LAC = MSS_Pars + LAC_Pars
            df_MSS_LACs.loc[LAC_count] = new_LAC
            LAC_count = LAC_count + 1
df_MSS_LACs
# Out:
#          MSS        Date      Time  MCC MNC LAC_str    LAC_NAME   AT  \
# 0    MSSBA06  2022-02-04  09:51:20  724  05   01671    LAC01671  001
# 1    MSSBA06  2022-02-04  09:51:20  724  05   02575     LAC2575  001
# 2    MSSBA06  2022-02-04  09:51:20  724  05   02775     LAC2775  001
# 3    MSSBA06  2022-02-04  09:51:20  724  05   01575     LAC1575  001
# 4    MSSBA06  2022-02-04  09:51:20  724  05   01475     LAC1475  001
# ..       ...         ...       ...  ...  ..     ...         ...  ...
# 430  MSSBA0A  2022-02-04  09:50:20  724  05   52079    LAC52079  001
# 431  MSSBA0A  2022-02-04  09:50:20  724  05   23875    LAC23875  001
# 432  MSSBA0A  2022-02-04  09:50:20  724  28   40675  LAC40675RS  001
# 433  MSSBA0A  2022-02-04  09:50:20  724  05   40675    LAC40675  001
# 434  MSSBA0A  2022-02-04  09:50:20  724  05   54175    LAC54175  001
#
#                     INT RNGP MNC_AL DSAV TZ HONLA
# 0    0600 ( x 10 msec )  001      -    -  -   001
# 1    0600 ( x 10 msec )  002      -    -  -   002
# 2    0600 ( x 10 msec )  002      -    -  -   002
# 3    0600 ( x 10 msec )  002      -    -  -   002
# 4    0600 ( x 10 msec )  002      -    -  -   002
# ..                  ...  ...    ...  ... ..   ...
# 430  0600 ( x 10 msec )  007      -    -  -   007
# 431  0600 ( x 10 msec )  004      -    -  -   004
# 432  0600 ( x 10 msec )  005      -    -  -   005
# 433  0600 ( x 10 msec )  005      -    -  -   005
# 434  0600 ( x 10 msec )  005      -    -  -   005
#
# [435 rows x 14 columns]

# %% [markdown]
# ### Analyze Data

# %%
# Working on it...

drop_col = ['AT', 'INT', 'RNGP', 'MNC_AL', 'DSAV', 'TZ', 'HONLA']
df_MSS_LAIs = df_MSS_LACs.drop(columns=drop_col)
df_MSS_LAIs['LAC_int'] =  df_MSS_LAIs['LAC_str'].astype(int)
df_MSS_LAIs['LAI'] =  df_MSS_LAIs['MCC'] + '-' + df_MSS_LAIs['MNC'] + '-' + df_MSS_LAIs['LAC_int'].astype(str)
df_MSS_LAIs['NE-LAI'] =  df_MSS_LAIs['MSS'] + '-' + df_MSS_LAIs['LAI']
df_MSS_LAIs
# Out:
#          MSS        Date      Time  MCC MNC LAC_str    LAC_NAME  LAC_int  \
# 0    MSSBA06  2022-02-04  09:51:20  724  05   01671    LAC01671     1671
# 1    MSSBA06  2022-02-04  09:51:20  724  05   02575     LAC2575     2575
# 2    MSSBA06  2022-02-04  09:51:20  724  05   02775     LAC2775     2775
# 3    MSSBA06  2022-02-04  09:51:20  724  05   01575     LAC1575     1575
# 4    MSSBA06  2022-02-04  09:51:20  724  05   01475     LAC1475     1475
# ..       ...         ...       ...  ...  ..     ...         ...      ...
# 430  MSSBA0A  2022-02-04  09:50:20  724  05   52079    LAC52079    52079
# 431  MSSBA0A  2022-02-04  09:50:20  724  05   23875    LAC23875    23875
# 432  MSSBA0A  2022-02-04  09:50:20  724  28   40675  LAC40675RS    40675
# 433  MSSBA0A  2022-02-04  09:50:20  724  05   40675    LAC40675    40675
# 434  MSSBA0A  2022-02-04  09:50:20  724  05   54175    LAC54175    54175
#
#               LAI                NE-LAI
# 0     724-05-1671   MSSBA06-724-05-1671
# 1     724-05-2575   MSSBA06-724-05-2575
# 2     724-05-2775   MSSBA06-724-05-2775
# 3     724-05-1575   MSSBA06-724-05-1575
# 4     724-05-1475   MSSBA06-724-05-1475
# ..            ...                   ...
# 430  724-05-52079  MSSBA0A-724-05-52079
# 431  724-05-23875  MSSBA0A-724-05-23875
# 432  724-28-40675  MSSBA0A-724-28-40675
# 433  724-05-40675  MSSBA0A-724-05-40675
# 434  724-05-54175  MSSBA0A-724-05-54175
#
# [435 rows x 10 columns]

# %%
df_MSS_LAIs['NE-LAI'].describe()
# Out:
# count                     435
# unique                    435
# top       MSSBA0A-724-05-1275
# freq                        1
# Name: NE-LAI, dtype: object

# %% [markdown]
# ### Plot + Insights

# %%
# Continue...

# %%
df_MSS_LACs.head()
# Out:
#        MSS        Date      Time  MCC MNC LAC_str  LAC_NAME   AT  \
# 0  MSSBA06  2022-02-04  09:51:20  724  05   01671  LAC01671  001
# 1  MSSBA06  2022-02-04  09:51:20  724  05   02575   LAC2575  001
# 2  MSSBA06  2022-02-04  09:51:20  724  05   02775   LAC2775  001
# 3  MSSBA06  2022-02-04  09:51:20  724  05   01575   LAC1575  001
# 4  MSSBA06  2022-02-04  09:51:20  724  05   01475   LAC1475  001
#
#                   INT RNGP MNC_AL DSAV TZ HONLA
# 0  0600 ( x 10 msec )  001      -    -  -   001
# 1  0600 ( x 10 msec )  002      -    -  -   002
# 2  0600 ( x 10 msec )  002      -    -  -   002
# 3  0600 ( x 10 msec )  002      -    -  -   002
# 4  0600 ( x 10 msec )  002      -    -  -   002

# %%
df_MSS_LACs.groupby('MSS')['AT'].count()
# Out:
# MSS
# MSSBA06     47
# MSSBA09    181
# MSSBA0A    207
# Name: AT, dtype: int64

# %%
df_MSS_LACs.describe(include='all')
# Out:
#             MSS        Date      Time  MCC  MNC LAC_str  LAC_NAME   AT  \
# count       435         435       435  435  435     435       435  435
# unique        3           1         3    1    3     352       426    1
# top     MSSBA0A  2022-02-04  09:50:20  724   05   32177  LAC20975  001
# freq        207         435       207  435  346       2         2  435
#
#                        INT RNGP MNC_AL DSAV   TZ HONLA
# count                  435  435    435  435  435   435
# unique                   1    9      2    1    1     9
# top     0600 ( x 10 msec )  005      -    -    -   005
# freq                   435  148    434  435  435   148

# %%
df_MSS_LACs['MSS'].describe(include='all')
# Out:
# count         435
# unique          3
# top       MSSBA0A
# freq          207
# Name: MSS, dtype: object

# %%
df_MSS_LACs.head()
# Out:
#        MSS        Date      Time  MCC MNC LAC_str  LAC_NAME   AT  \
# 0  MSSBA06  2022-02-04  09:51:20  724  05   01671  LAC01671  001
# 1  MSSBA06  2022-02-04  09:51:20  724  05   02575   LAC2575  001
# 2  MSSBA06  2022-02-04  09:51:20  724  05   02775   LAC2775  001
# 3  MSSBA06  2022-02-04  09:51:20  724  05   01575   LAC1575  001
# 4  MSSBA06  2022-02-04  09:51:20  724  05   01475   LAC1475  001
#
#                   INT RNGP MNC_AL DSAV TZ HONLA
# 0  0600 ( x 10 msec )  001      -    -  -   001
# 1  0600 ( x 10 msec )  002      -    -  -   002
# 2  0600 ( x 10 msec )  002      -    -  -   002
# 3  0600 ( x 10 msec )  002      -    -  -   002
# 4  0600 ( x 10 msec )  002      -    -  -   002

# %%
df_MSS_LACs['AT'].count()
# Out:
# 435

# %%
df_MSS_LACs
# Out:
#          MSS        Date      Time  MCC MNC LAC_str    LAC_NAME   AT  \
# 0    MSSBA06  2022-02-04  09:51:20  724  05   01671    LAC01671  001
# 1    MSSBA06  2022-02-04  09:51:20  724  05   02575     LAC2575  001
# 2    MSSBA06  2022-02-04  09:51:20  724  05   02775     LAC2775  001
# 3    MSSBA06  2022-02-04  09:51:20  724  05   01575     LAC1575  001
# 4    MSSBA06  2022-02-04  09:51:20  724  05   01475     LAC1475  001
# ..       ...         ...       ...  ...  ..     ...         ...  ...
# 430  MSSBA0A  2022-02-04  09:50:20  724  05   52079    LAC52079  001
# 431  MSSBA0A  2022-02-04  09:50:20  724  05   23875    LAC23875  001
# 432  MSSBA0A  2022-02-04  09:50:20  724  28   40675  LAC40675RS  001
# 433  MSSBA0A  2022-02-04  09:50:20  724  05   40675    LAC40675  001
# 434  MSSBA0A  2022-02-04  09:50:20  724  05   54175    LAC54175  001
#
#                     INT RNGP MNC_AL DSAV TZ HONLA
# 0    0600 ( x 10 msec )  001      -    -  -   001
# 1    0600 ( x 10 msec )  002      -    -  -   002
# 2    0600 ( x 10 msec )  002      -    -  -   002
# 3    0600 ( x 10 msec )  002      -    -  -   002
# 4    0600 ( x 10 msec )  002      -    -  -   002
# ..                  ...  ...    ...  ... ..   ...
# 430  0600 ( x 10 msec )  007      -    -  -   007
# 431  0600 ( x 10 msec )  004      -    -  -   004
# 432  0600 ( x 10 msec )  005      -    -  -   005
# 433  0600 ( x 10 msec )  005      -    -  -   005
# 434  0600 ( x 10 msec )  005      -    -  -   005
#
# [435 rows x 14 columns]

# %%
df_MSS_LACs.dropna().describe()
# Out:
#             MSS        Date      Time  MCC  MNC LAC_str  LAC_NAME   AT  \
# count       435         435       435  435  435     435       435  435
# unique        3           1         3    1    3     352       426    1
# top     MSSBA0A  2022-02-04  09:50:20  724   05   32177  LAC20975  001
# freq        207         435       207  435  346       2         2  435
#
#                        INT RNGP MNC_AL DSAV   TZ HONLA
# count                  435  435    435  435  435   435
# unique                   1    9      2    1    1     9
# top     0600 ( x 10 msec )  005      -    -    -   005
# freq                   435  148    434  435  435   148

# %%
df_MSS_LACs.groupby('MSS', axis=1).count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alvaro\OneDrive\My Files\Programming\Python\2022 - Jupyter Notebooks\Macro ZELO MSS.ipynb Cell 39' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alvaro/OneDrive/My%20Files/Programming/Python/2022%20-%20Jupyter%20Notebooks/Macro%20ZELO%20MSS.ipynb#ch0000038?line=0'>1</a> df_MSS_LACs.groupby('MSS', axis=1).count()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1748, in DataFrameGroupBy.count(self)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1744'>1745</a>     counted = lib.count_level_2d(masked, labels=ids, max_bin=ngroups, axis=1)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1745'>1746</a>     return counted
# -> <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1747'>1748</a> new_mgr = data.apply(hfunc)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1749'>1750</a> # If we are grouping on categoricals we want unobserved categories to
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1750'>1751</a> # return zero, rather than the default of NaN which the reindexing in
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1751'>1752</a> # _wrap_agged_blocks() returns. GH 35028
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1752'>1753</a> with com.temp_setattr(self, "observed", True):
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:425, in BlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/managers.py?line=422'>423</a> try:
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/managers.py?line=423'>424</a>     if callable(f):
# --> <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/managers.py?line=424'>425</a>         applied = b.apply(f, **kwargs)
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/managers.py?line=425'>426</a>     else:
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/managers.py?line=426'>427</a>         applied = getattr(b, f)(**kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:378, in Block.apply(self, func, **kwargs)
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=372'>373</a> """
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=373'>374</a> apply the function to my values; return a block if we are not
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=374'>375</a> one
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=375'>376</a> """
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=376'>377</a> with np.errstate(all="ignore"):
# --> <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=377'>378</a>     result = func(self.values, **kwargs)
#     <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/internals/blocks.py?line=379'>380</a> return self._split_op_result(result)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1743, in DataFrameGroupBy.count.<locals>.hfunc(bvalues)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1740'>1741</a>     masked = mask & ~isna(bvalues).reshape(1, -1)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1741'>1742</a> else:
# -> <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1742'>1743</a>     masked = mask & ~isna(bvalues)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1744'>1745</a> counted = lib.count_level_2d(masked, labels=ids, max_bin=ngroups, axis=1)
#    <a href='file:///~/Anaconda3/lib/site-packages/pandas/core/groupby/generic.py?line=1745'>1746</a> return counted
#
# ValueError: operands could not be broadcast together with shapes (14,) (435,13)
