# %% [markdown]
# # Change LAI of 2G & 3G cells in Ericsson's MSSs

# %% [markdown]
# ## Import modules

# %%
# Import modules (NOK_ERI_Toolkit) & others that will be needed along the program
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import NOK_ERI_Toolkit as NOK_ERI_Toolkit

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load 2G & 3G data form "Change LAI - Python Template.xlsx"

# %% [markdown]
# ## REMEMBER TO UPDATE THE NAME OF THE TEMPLATE

# %%
# Especify the path to the file and read the template
ERI_path_to_file = 'C:/Users/Alvaro/OneDrive/My Files/_Scripts_Models/Commands Generators/Change LAI - Python Template v2.xlsx'
xls = pd.ExcelFile(ERI_path_to_file)                                                                                        #Read excel file

# %%
# Create DataFrame for 2G data & clean it up
df_eri_2g = pd.read_excel(xls, sheet_name='ERI_2G', dtype=str) #Read specific sheet | dtype=str forces to read as string to avoid lose '0s'
df_eri_2g['New CGI'] = df_eri_2g['MCC'] + '-' + df_eri_2g['MNC'] + '-' + df_eri_2g['New LAC'] + '-' + df_eri_2g['CI/SA']    # Create col New_CGI
df_eri_2g['DE-PARA'] = 'de LAC=' + df_eri_2g['LAC'] + ' para LAC=' + df_eri_2g['New LAC']                                   # Create col DE-PARA
df_eri_2g = df_eri_2g.sort_values(by=['MSS', 'Municipio', 'NE', 'CELL_NAME'], ignore_index=True)                            # Sort DataFrame

# %%
# Create DataFrame for 3G data & clean it up
df_eri_3g = pd.read_excel(xls, sheet_name='ERI_3G', dtype=str) #Read specific sheet | dtype=str forces to read as string to avoid lose '0s'
df_eri_3g['New CGI'] = df_eri_3g['MCC'] + '-' + df_eri_3g['MNC'] + '-' + df_eri_3g['New LAC'] + '-' + df_eri_3g['CI/SA']    # Create col New_CGI
df_eri_3g['DE-PARA'] = 'de LAC=' + df_eri_3g['LAC'] + ' para LAC=' + df_eri_3g['New LAC']                                   # Create col DE-PARA
df_eri_3g = df_eri_3g.sort_values(by=['MSS', 'Municipio', 'NE', 'CELL_NAME'], ignore_index=True)                            # Sort DataFrame

# %% [markdown]
# ## Print "change" 2G commands

# %%
# Get the "change" commands
NOK_ERI_Toolkit.change_lai_2g_eri(my_df=df_eri_2g, my_cmd='change')
# Out:
# ! BLMNOPOLIS | Change de LAC=73 para LAC=20573
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9BLM011;
# MGCEP:CELL=9BLM012;
# MGCEP:CELL=9BLM013;
# MGCEP:CELL=9BLM015;
# MGRCP:CELL=9BLM011;
# MGRCP:CELL=9BLM012;
# MGRCP:CELL=9BLM013;
# MGRCP:CELL=9BLM015;
# MGCEE:CELL=9BLM011;
# MGCEE:CELL=9BLM012;
# MGCEE:CELL=9BLM013;
# MGCEE:CELL=9BLM015;
# MGCEI:CELL=9BLM011,BSC=BSCBA45,CGI=724-05-20573-119;
# MGCEI:CELL=9BLM012,BSC=BSCBA45,CGI=724-05-20573-10119;
# MGCEI:CELL=9BLM013,BSC=BSCBA45,CGI=724-05-20573-20119;
# MGCEI:CELL=9BLM015,BSC=BSCBA45,CGI=724-05-20573-40119;
# MGCEC:CELL=9BLM011,EA=73;
# MGCEC:CELL=9BLM012,EA=73;
# MGCEC:CELL=9BLM013,EA=73;
# MGCEC:CELL=9BLM015,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CACOPOLIS | Change de LAC=73 para LAC=20673
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9CAC011;
# MGCEP:CELL=9CAC021;
# MGCEP:CELL=9CAC022;
# MGRCP:CELL=9CAC011;
# MGRCP:CELL=9CAC021;
# MGRCP:CELL=9CAC022;
# MGCEE:CELL=9CAC011;
# MGCEE:CELL=9CAC021;
# MGCEE:CELL=9CAC022;
# MGCEI:CELL=9CAC011,BSC=BSCBA45,CGI=724-05-20673-120;
# MGCEI:CELL=9CAC021,BSC=BSCBA45,CGI=724-05-20673-220;
# MGCEI:CELL=9CAC022,BSC=BSCBA45,CGI=724-05-20673-10220;
# MGCEC:CELL=9CAC011,EA=73;
# MGCEC:CELL=9CAC021,EA=73;
# MGCEC:CELL=9CAC022,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! EUSOPOLIS | Change de LAC=773 para LAC=20773
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9EUS041;
# MGCEP:CELL=9EUS042;
# MGCEP:CELL=9EUS043;
# MGCEP:CELL=9EUS121;
# MGCEP:CELL=9EUS122;
# MGCEP:CELL=9EUS123;
# MGRCP:CELL=9EUS041;
# MGRCP:CELL=9EUS042;
# MGRCP:CELL=9EUS043;
# MGRCP:CELL=9EUS121;
# MGRCP:CELL=9EUS122;
# MGRCP:CELL=9EUS123;
# MGCEE:CELL=9EUS041;
# MGCEE:CELL=9EUS042;
# MGCEE:CELL=9EUS043;
# MGCEE:CELL=9EUS121;
# MGCEE:CELL=9EUS122;
# MGCEE:CELL=9EUS123;
# MGCEI:CELL=9EUS041,BSC=BSCBA45,CGI=724-05-20773-404;
# MGCEI:CELL=9EUS042,BSC=BSCBA45,CGI=724-05-20773-10404;
# MGCEI:CELL=9EUS043,BSC=BSCBA45,CGI=724-05-20773-20404;
# MGCEI:CELL=9EUS121,BSC=BSCBA45,CGI=724-05-20773-1204;
# MGCEI:CELL=9EUS122,BSC=BSCBA45,CGI=724-05-20773-11204;
# MGCEI:CELL=9EUS123,BSC=BSCBA45,CGI=724-05-20773-21204;
# MGCEC:CELL=9EUS041,EA=73;
# MGCEC:CELL=9EUS042,EA=73;
# MGCEC:CELL=9EUS043,EA=73;
# MGCEC:CELL=9EUS121,EA=73;
# MGCEC:CELL=9EUS122,EA=73;
# MGCEC:CELL=9EUS123,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! LAJEDÃO | Change de LAC=21973 para LAC=20473
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9LDO011;
# MGCEP:CELL=9LDO014;
# MGCEP:CELL=9LDO015;
# MGCEP:CELL=9LDO016;
# MGRCP:CELL=9LDO011;
# MGRCP:CELL=9LDO014;
# MGRCP:CELL=9LDO015;
# MGRCP:CELL=9LDO016;
# MGCEE:CELL=9LDO011;
# MGCEE:CELL=9LDO014;
# MGCEE:CELL=9LDO015;
# MGCEE:CELL=9LDO016;
# MGCEI:CELL=9LDO011,BSC=BSCBA45,CGI=724-05-20473-142;
# MGCEI:CELL=9LDO014,BSC=BSCBA45,CGI=724-05-20473-30142;
# MGCEI:CELL=9LDO015,BSC=BSCBA45,CGI=724-05-20473-40142;
# MGCEI:CELL=9LDO016,BSC=BSCBA45,CGI=724-05-20473-50142;
# MGCEC:CELL=9LDO011,EA=73;
# MGCEC:CELL=9LDO014,EA=73;
# MGCEC:CELL=9LDO015,EA=73;
# MGCEC:CELL=9LDO016,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
# True

# %% [markdown]
# ## Print "fallback" 2G commands

# %%
# Get the "fallback" commands
NOK_ERI_Toolkit.change_lai_2g_eri(my_df=df_eri_2g, my_cmd='fallback')
# Out:
# ! BLMNOPOLIS | Fallback de LAC=73 para LAC=20573
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9BLM011;
# MGCEP:CELL=9BLM012;
# MGCEP:CELL=9BLM013;
# MGCEP:CELL=9BLM015;
# MGRCP:CELL=9BLM011;
# MGRCP:CELL=9BLM012;
# MGRCP:CELL=9BLM013;
# MGRCP:CELL=9BLM015;
# MGCEE:CELL=9BLM011;
# MGCEE:CELL=9BLM012;
# MGCEE:CELL=9BLM013;
# MGCEE:CELL=9BLM015;
# MGCEI:CELL=9BLM011,BSC=BSCBA45,CGI=724-05-73-119;
# MGCEI:CELL=9BLM012,BSC=BSCBA45,CGI=724-05-73-10119;
# MGCEI:CELL=9BLM013,BSC=BSCBA45,CGI=724-05-73-20119;
# MGCEI:CELL=9BLM015,BSC=BSCBA45,CGI=724-05-73-40119;
# MGCEC:CELL=9BLM011,EA=73;
# MGCEC:CELL=9BLM012,EA=73;
# MGCEC:CELL=9BLM013,EA=73;
# MGCEC:CELL=9BLM015,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! CACOPOLIS | Fallback de LAC=73 para LAC=20673
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9CAC011;
# MGCEP:CELL=9CAC021;
# MGCEP:CELL=9CAC022;
# MGRCP:CELL=9CAC011;
# MGRCP:CELL=9CAC021;
# MGRCP:CELL=9CAC022;
# MGCEE:CELL=9CAC011;
# MGCEE:CELL=9CAC021;
# MGCEE:CELL=9CAC022;
# MGCEI:CELL=9CAC011,BSC=BSCBA45,CGI=724-05-73-120;
# MGCEI:CELL=9CAC021,BSC=BSCBA45,CGI=724-05-73-220;
# MGCEI:CELL=9CAC022,BSC=BSCBA45,CGI=724-05-73-10220;
# MGCEC:CELL=9CAC011,EA=73;
# MGCEC:CELL=9CAC021,EA=73;
# MGCEC:CELL=9CAC022,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! EUSOPOLIS | Fallback de LAC=773 para LAC=20773
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9EUS041;
# MGCEP:CELL=9EUS042;
# MGCEP:CELL=9EUS043;
# MGCEP:CELL=9EUS121;
# MGCEP:CELL=9EUS122;
# MGCEP:CELL=9EUS123;
# MGRCP:CELL=9EUS041;
# MGRCP:CELL=9EUS042;
# MGRCP:CELL=9EUS043;
# MGRCP:CELL=9EUS121;
# MGRCP:CELL=9EUS122;
# MGRCP:CELL=9EUS123;
# MGCEE:CELL=9EUS041;
# MGCEE:CELL=9EUS042;
# MGCEE:CELL=9EUS043;
# MGCEE:CELL=9EUS121;
# MGCEE:CELL=9EUS122;
# MGCEE:CELL=9EUS123;
# MGCEI:CELL=9EUS041,BSC=BSCBA45,CGI=724-05-773-404;
# MGCEI:CELL=9EUS042,BSC=BSCBA45,CGI=724-05-773-10404;
# MGCEI:CELL=9EUS043,BSC=BSCBA45,CGI=724-05-773-20404;
# MGCEI:CELL=9EUS121,BSC=BSCBA45,CGI=724-05-773-1204;
# MGCEI:CELL=9EUS122,BSC=BSCBA45,CGI=724-05-773-11204;
# MGCEI:CELL=9EUS123,BSC=BSCBA45,CGI=724-05-773-21204;
# MGCEC:CELL=9EUS041,EA=73;
# MGCEC:CELL=9EUS042,EA=73;
# MGCEC:CELL=9EUS043,EA=73;
# MGCEC:CELL=9EUS121,EA=73;
# MGCEC:CELL=9EUS122,EA=73;
# MGCEC:CELL=9EUS123,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! LAJEDÃO | Fallback de LAC=21973 para LAC=20473
# !--------------------------------------------------------------------------------------
# MGCEP:CELL=9LDO011;
# MGCEP:CELL=9LDO014;
# MGCEP:CELL=9LDO015;
# MGCEP:CELL=9LDO016;
# MGRCP:CELL=9LDO011;
# MGRCP:CELL=9LDO014;
# MGRCP:CELL=9LDO015;
# MGRCP:CELL=9LDO016;
# MGCEE:CELL=9LDO011;
# MGCEE:CELL=9LDO014;
# MGCEE:CELL=9LDO015;
# MGCEE:CELL=9LDO016;
# MGCEI:CELL=9LDO011,BSC=BSCBA45,CGI=724-05-21973-142;
# MGCEI:CELL=9LDO014,BSC=BSCBA45,CGI=724-05-21973-30142;
# MGCEI:CELL=9LDO015,BSC=BSCBA45,CGI=724-05-21973-40142;
# MGCEI:CELL=9LDO016,BSC=BSCBA45,CGI=724-05-21973-50142;
# MGCEC:CELL=9LDO011,EA=73;
# MGCEC:CELL=9LDO014,EA=73;
# MGCEC:CELL=9LDO015,EA=73;
# MGCEC:CELL=9LDO016,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
# True

# %% [markdown]
# ## Print "change" 3G commands

# %%
# Get the "change" commands
NOK_ERI_Toolkit.change_lai_3g_eri(my_df=df_eri_3g, my_cmd='change')
# Out:
# ! ARATACA | Change de LAC=30173 para LAC=30773
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IATW01A;
# MGAAP:AREA=IATW01B;
# MGAAP:AREA=IATW01C;
# MGAAP:AREA=IATW01E;
# MGAAP:AREA=IATW01F;
# MGAAP:AREA=IATW01G;
# MGRCP:AREA=IATW01A;
# MGRCP:AREA=IATW01B;
# MGRCP:AREA=IATW01C;
# MGRCP:AREA=IATW01E;
# MGRCP:AREA=IATW01F;
# MGRCP:AREA=IATW01G;
# MGAAE:AREA=IATW01A;
# MGAAE:AREA=IATW01B;
# MGAAE:AREA=IATW01C;
# MGAAE:AREA=IATW01E;
# MGAAE:AREA=IATW01F;
# MGAAE:AREA=IATW01G;
# MGAAI:AREA=IATW01A,SAI=724-05-30773-61050;
# MGAAI:AREA=IATW01B,SAI=724-05-30773-61051;
# MGAAI:AREA=IATW01C,SAI=724-05-30773-61052;
# MGAAI:AREA=IATW01E,SAI=724-05-30773-64650;
# MGAAI:AREA=IATW01F,SAI=724-05-30773-64651;
# MGAAI:AREA=IATW01G,SAI=724-05-30773-64652;
# MGAAC:AREA=IATW01A,EA=73;
# MGAAC:AREA=IATW01B,EA=73;
# MGAAC:AREA=IATW01C,EA=73;
# MGAAC:AREA=IATW01E,EA=73;
# MGAAC:AREA=IATW01F,EA=73;
# MGAAC:AREA=IATW01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! BARRA | Change de LAC=30174 para LAC=32173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IBAA01A;
# MGAAP:AREA=IBAA01B;
# MGAAP:AREA=IBAA01C;
# MGAAP:AREA=IBAA01E;
# MGAAP:AREA=IBAA01F;
# MGAAP:AREA=IBAA01G;
# MGAAP:AREA=IBAA03A;
# MGAAP:AREA=IBAA03B;
# MGAAP:AREA=IBAA03C;
# MGAAP:AREA=IBAA03E;
# MGAAP:AREA=IBAA03F;
# MGAAP:AREA=IBAA03G;
# MGRCP:AREA=IBAA01A;
# MGRCP:AREA=IBAA01B;
# MGRCP:AREA=IBAA01C;
# MGRCP:AREA=IBAA01E;
# MGRCP:AREA=IBAA01F;
# MGRCP:AREA=IBAA01G;
# MGRCP:AREA=IBAA03A;
# MGRCP:AREA=IBAA03B;
# MGRCP:AREA=IBAA03C;
# MGRCP:AREA=IBAA03E;
# MGRCP:AREA=IBAA03F;
# MGRCP:AREA=IBAA03G;
# MGAAE:AREA=IBAA01A;
# MGAAE:AREA=IBAA01B;
# MGAAE:AREA=IBAA01C;
# MGAAE:AREA=IBAA01E;
# MGAAE:AREA=IBAA01F;
# MGAAE:AREA=IBAA01G;
# MGAAE:AREA=IBAA03A;
# MGAAE:AREA=IBAA03B;
# MGAAE:AREA=IBAA03C;
# MGAAE:AREA=IBAA03E;
# MGAAE:AREA=IBAA03F;
# MGAAE:AREA=IBAA03G;
# MGAAI:AREA=IBAA01A,SAI=724-05-32173-62370;
# MGAAI:AREA=IBAA01B,SAI=724-05-32173-62371;
# MGAAI:AREA=IBAA01C,SAI=724-05-32173-62372;
# MGAAI:AREA=IBAA01E,SAI=724-05-32173-62373;
# MGAAI:AREA=IBAA01F,SAI=724-05-32173-62374;
# MGAAI:AREA=IBAA01G,SAI=724-05-32173-62375;
# MGAAI:AREA=IBAA03A,SAI=724-05-32173-64760;
# MGAAI:AREA=IBAA03B,SAI=724-05-32173-64761;
# MGAAI:AREA=IBAA03C,SAI=724-05-32173-64762;
# MGAAI:AREA=IBAA03E,SAI=724-05-32173-64763;
# MGAAI:AREA=IBAA03F,SAI=724-05-32173-64764;
# MGAAI:AREA=IBAA03G,SAI=724-05-32173-64765;
# MGAAC:AREA=IBAA01A,EA=73;
# MGAAC:AREA=IBAA01B,EA=73;
# MGAAC:AREA=IBAA01C,EA=73;
# MGAAC:AREA=IBAA01E,EA=73;
# MGAAC:AREA=IBAA01F,EA=73;
# MGAAC:AREA=IBAA01G,EA=73;
# MGAAC:AREA=IBAA03A,EA=73;
# MGAAC:AREA=IBAA03B,EA=73;
# MGAAC:AREA=IBAA03C,EA=73;
# MGAAC:AREA=IBAA03E,EA=73;
# MGAAC:AREA=IBAA03F,EA=73;
# MGAAC:AREA=IBAA03G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! JABORANDI | Change de LAC=30177 para LAC=33177
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IJBI04A;
# MGAAP:AREA=IJBI04E;
# MGRCP:AREA=IJBI04A;
# MGRCP:AREA=IJBI04E;
# MGAAE:AREA=IJBI04A;
# MGAAE:AREA=IJBI04E;
# MGAAI:AREA=IJBI04A,SAI=724-05-33177-30284;
# MGAAI:AREA=IJBI04E,SAI=724-05-33177-30285;
# MGAAC:AREA=IJBI04A,EA=77;
# MGAAC:AREA=IJBI04E,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! DIAS D'ÁVILA | Change de LAC=30671 para LAC=32271
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IDSA01A;
# MGAAP:AREA=IDSA01B;
# MGAAP:AREA=IDSA01C;
# MGAAP:AREA=IDSA01I;
# MGAAP:AREA=IDSA01J;
# MGAAP:AREA=IDSA01K;
# MGAAP:AREA=IDSA02A;
# MGAAP:AREA=IDSA02B;
# MGAAP:AREA=IDSA02C;
# MGAAP:AREA=IDSA02I;
# MGAAP:AREA=IDSA02J;
# MGAAP:AREA=IDSA02K;
# MGAAP:AREA=IDSA03A;
# MGAAP:AREA=IDSA03B;
# MGAAP:AREA=IDSA03C;
# MGAAP:AREA=IDSA03I;
# MGAAP:AREA=IDSA03J;
# MGAAP:AREA=IDSA03K;
# MGAAP:AREA=IDSA04A;
# MGAAP:AREA=IDSA04B;
# MGAAP:AREA=IDSA04C;
# MGAAP:AREA=IDSA04I;
# MGAAP:AREA=IDSA04J;
# MGAAP:AREA=IDSA04K;
# MGAAP:AREA=IDSA08A;
# MGAAP:AREA=IDSA08B;
# MGAAP:AREA=IDSA08C;
# MGAAP:AREA=IDSA08E;
# MGAAP:AREA=IDSA08F;
# MGAAP:AREA=IDSA08G;
# MGAAP:AREA=IDSA09A;
# MGAAP:AREA=IDSA09B;
# MGAAP:AREA=IDSA09C;
# MGAAP:AREA=IDSA09E;
# MGAAP:AREA=IDSA09F;
# MGAAP:AREA=IDSA09G;
# MGAAP:AREA=IDSA10A;
# MGAAP:AREA=IDSA10B;
# MGAAP:AREA=IDSA10C;
# MGAAP:AREA=IDSA10E;
# MGAAP:AREA=IDSA10F;
# MGAAP:AREA=IDSA10G;
# MGAAP:AREA=IDSA12A;
# MGAAP:AREA=IDSA12B;
# MGAAP:AREA=IDSA12C;
# MGAAP:AREA=IDSA12E;
# MGAAP:AREA=IDSA12F;
# MGAAP:AREA=IDSA12G;
# MGRCP:AREA=IDSA01A;
# MGRCP:AREA=IDSA01B;
# MGRCP:AREA=IDSA01C;
# MGRCP:AREA=IDSA01I;
# MGRCP:AREA=IDSA01J;
# MGRCP:AREA=IDSA01K;
# MGRCP:AREA=IDSA02A;
# MGRCP:AREA=IDSA02B;
# MGRCP:AREA=IDSA02C;
# MGRCP:AREA=IDSA02I;
# MGRCP:AREA=IDSA02J;
# MGRCP:AREA=IDSA02K;
# MGRCP:AREA=IDSA03A;
# MGRCP:AREA=IDSA03B;
# MGRCP:AREA=IDSA03C;
# MGRCP:AREA=IDSA03I;
# MGRCP:AREA=IDSA03J;
# MGRCP:AREA=IDSA03K;
# MGRCP:AREA=IDSA04A;
# MGRCP:AREA=IDSA04B;
# MGRCP:AREA=IDSA04C;
# MGRCP:AREA=IDSA04I;
# MGRCP:AREA=IDSA04J;
# MGRCP:AREA=IDSA04K;
# MGRCP:AREA=IDSA08A;
# MGRCP:AREA=IDSA08B;
# MGRCP:AREA=IDSA08C;
# MGRCP:AREA=IDSA08E;
# MGRCP:AREA=IDSA08F;
# MGRCP:AREA=IDSA08G;
# MGRCP:AREA=IDSA09A;
# MGRCP:AREA=IDSA09B;
# MGRCP:AREA=IDSA09C;
# MGRCP:AREA=IDSA09E;
# MGRCP:AREA=IDSA09F;
# MGRCP:AREA=IDSA09G;
# MGRCP:AREA=IDSA10A;
# MGRCP:AREA=IDSA10B;
# MGRCP:AREA=IDSA10C;
# MGRCP:AREA=IDSA10E;
# MGRCP:AREA=IDSA10F;
# MGRCP:AREA=IDSA10G;
# MGRCP:AREA=IDSA12A;
# MGRCP:AREA=IDSA12B;
# MGRCP:AREA=IDSA12C;
# MGRCP:AREA=IDSA12E;
# MGRCP:AREA=IDSA12F;
# MGRCP:AREA=IDSA12G;
# MGAAE:AREA=IDSA01A;
# MGAAE:AREA=IDSA01B;
# MGAAE:AREA=IDSA01C;
# MGAAE:AREA=IDSA01I;
# MGAAE:AREA=IDSA01J;
# MGAAE:AREA=IDSA01K;
# MGAAE:AREA=IDSA02A;
# MGAAE:AREA=IDSA02B;
# MGAAE:AREA=IDSA02C;
# MGAAE:AREA=IDSA02I;
# MGAAE:AREA=IDSA02J;
# MGAAE:AREA=IDSA02K;
# MGAAE:AREA=IDSA03A;
# MGAAE:AREA=IDSA03B;
# MGAAE:AREA=IDSA03C;
# MGAAE:AREA=IDSA03I;
# MGAAE:AREA=IDSA03J;
# MGAAE:AREA=IDSA03K;
# MGAAE:AREA=IDSA04A;
# MGAAE:AREA=IDSA04B;
# MGAAE:AREA=IDSA04C;
# MGAAE:AREA=IDSA04I;
# MGAAE:AREA=IDSA04J;
# MGAAE:AREA=IDSA04K;
# MGAAE:AREA=IDSA08A;
# MGAAE:AREA=IDSA08B;
# MGAAE:AREA=IDSA08C;
# MGAAE:AREA=IDSA08E;
# MGAAE:AREA=IDSA08F;
# MGAAE:AREA=IDSA08G;
# MGAAE:AREA=IDSA09A;
# MGAAE:AREA=IDSA09B;
# MGAAE:AREA=IDSA09C;
# MGAAE:AREA=IDSA09E;
# MGAAE:AREA=IDSA09F;
# MGAAE:AREA=IDSA09G;
# MGAAE:AREA=IDSA10A;
# MGAAE:AREA=IDSA10B;
# MGAAE:AREA=IDSA10C;
# MGAAE:AREA=IDSA10E;
# MGAAE:AREA=IDSA10F;
# MGAAE:AREA=IDSA10G;
# MGAAE:AREA=IDSA12A;
# MGAAE:AREA=IDSA12B;
# MGAAE:AREA=IDSA12C;
# MGAAE:AREA=IDSA12E;
# MGAAE:AREA=IDSA12F;
# MGAAE:AREA=IDSA12G;
# MGAAI:AREA=IDSA01A,SAI=724-05-32271-115;
# MGAAI:AREA=IDSA01B,SAI=724-05-32271-10115;
# MGAAI:AREA=IDSA01C,SAI=724-05-32271-20115;
# MGAAI:AREA=IDSA01I,SAI=724-05-32271-40115;
# MGAAI:AREA=IDSA01J,SAI=724-05-32271-50115;
# MGAAI:AREA=IDSA01K,SAI=724-05-32271-60115;
# MGAAI:AREA=IDSA02A,SAI=724-05-32271-215;
# MGAAI:AREA=IDSA02B,SAI=724-05-32271-10215;
# MGAAI:AREA=IDSA02C,SAI=724-05-32271-20215;
# MGAAI:AREA=IDSA02I,SAI=724-05-32271-40215;
# MGAAI:AREA=IDSA02J,SAI=724-05-32271-50215;
# MGAAI:AREA=IDSA02K,SAI=724-05-32271-60215;
# MGAAI:AREA=IDSA03A,SAI=724-05-32271-315;
# MGAAI:AREA=IDSA03B,SAI=724-05-32271-10315;
# MGAAI:AREA=IDSA03C,SAI=724-05-32271-20315;
# MGAAI:AREA=IDSA03I,SAI=724-05-32271-40315;
# MGAAI:AREA=IDSA03J,SAI=724-05-32271-50315;
# MGAAI:AREA=IDSA03K,SAI=724-05-32271-60315;
# MGAAI:AREA=IDSA04A,SAI=724-05-32271-415;
# MGAAI:AREA=IDSA04B,SAI=724-05-32271-10415;
# MGAAI:AREA=IDSA04C,SAI=724-05-32271-20415;
# MGAAI:AREA=IDSA04I,SAI=724-05-32271-40415;
# MGAAI:AREA=IDSA04J,SAI=724-05-32271-50415;
# MGAAI:AREA=IDSA04K,SAI=724-05-32271-60415;
# MGAAI:AREA=IDSA08A,SAI=724-05-32271-60012;
# MGAAI:AREA=IDSA08B,SAI=724-05-32271-60013;
# MGAAI:AREA=IDSA08C,SAI=724-05-32271-60014;
# MGAAI:AREA=IDSA08E,SAI=724-05-32271-60015;
# MGAAI:AREA=IDSA08F,SAI=724-05-32271-60016;
# MGAAI:AREA=IDSA08G,SAI=724-05-32271-60017;
# MGAAI:AREA=IDSA09A,SAI=724-05-32271-60037;
# MGAAI:AREA=IDSA09B,SAI=724-05-32271-60038;
# MGAAI:AREA=IDSA09C,SAI=724-05-32271-60039;
# MGAAI:AREA=IDSA09E,SAI=724-05-32271-60040;
# MGAAI:AREA=IDSA09F,SAI=724-05-32271-60041;
# MGAAI:AREA=IDSA09G,SAI=724-05-32271-60042;
# MGAAI:AREA=IDSA10A,SAI=724-05-32271-60940;
# MGAAI:AREA=IDSA10B,SAI=724-05-32271-60941;
# MGAAI:AREA=IDSA10C,SAI=724-05-32271-60942;
# MGAAI:AREA=IDSA10E,SAI=724-05-32271-60943;
# MGAAI:AREA=IDSA10F,SAI=724-05-32271-60944;
# MGAAI:AREA=IDSA10G,SAI=724-05-32271-60945;
# MGAAI:AREA=IDSA12A,SAI=724-05-32271-60362;
# MGAAI:AREA=IDSA12B,SAI=724-05-32271-60363;
# MGAAI:AREA=IDSA12C,SAI=724-05-32271-60364;
# MGAAI:AREA=IDSA12E,SAI=724-05-32271-60365;
# MGAAI:AREA=IDSA12F,SAI=724-05-32271-60366;
# MGAAI:AREA=IDSA12G,SAI=724-05-32271-60367;
# MGAAC:AREA=IDSA01A,EA=71;
# MGAAC:AREA=IDSA01B,EA=71;
# MGAAC:AREA=IDSA01C,EA=71;
# MGAAC:AREA=IDSA01I,EA=71;
# MGAAC:AREA=IDSA01J,EA=71;
# MGAAC:AREA=IDSA01K,EA=71;
# MGAAC:AREA=IDSA02A,EA=71;
# MGAAC:AREA=IDSA02B,EA=71;
# MGAAC:AREA=IDSA02C,EA=71;
# MGAAC:AREA=IDSA02I,EA=71;
# MGAAC:AREA=IDSA02J,EA=71;
# MGAAC:AREA=IDSA02K,EA=71;
# MGAAC:AREA=IDSA03A,EA=71;
# MGAAC:AREA=IDSA03B,EA=71;
# MGAAC:AREA=IDSA03C,EA=71;
# MGAAC:AREA=IDSA03I,EA=71;
# MGAAC:AREA=IDSA03J,EA=71;
# MGAAC:AREA=IDSA03K,EA=71;
# MGAAC:AREA=IDSA04A,EA=71;
# MGAAC:AREA=IDSA04B,EA=71;
# MGAAC:AREA=IDSA04C,EA=71;
# MGAAC:AREA=IDSA04I,EA=71;
# MGAAC:AREA=IDSA04J,EA=71;
# MGAAC:AREA=IDSA04K,EA=71;
# MGAAC:AREA=IDSA08A,EA=71;
# MGAAC:AREA=IDSA08B,EA=71;
# MGAAC:AREA=IDSA08C,EA=71;
# MGAAC:AREA=IDSA08E,EA=71;
# MGAAC:AREA=IDSA08F,EA=71;
# MGAAC:AREA=IDSA08G,EA=71;
# MGAAC:AREA=IDSA09A,EA=71;
# MGAAC:AREA=IDSA09B,EA=71;
# MGAAC:AREA=IDSA09C,EA=71;
# MGAAC:AREA=IDSA09E,EA=71;
# MGAAC:AREA=IDSA09F,EA=71;
# MGAAC:AREA=IDSA09G,EA=71;
# MGAAC:AREA=IDSA10A,EA=71;
# MGAAC:AREA=IDSA10B,EA=71;
# MGAAC:AREA=IDSA10C,EA=71;
# MGAAC:AREA=IDSA10E,EA=71;
# MGAAC:AREA=IDSA10F,EA=71;
# MGAAC:AREA=IDSA10G,EA=71;
# MGAAC:AREA=IDSA12A,EA=71;
# MGAAC:AREA=IDSA12B,EA=71;
# MGAAC:AREA=IDSA12C,EA=71;
# MGAAC:AREA=IDSA12E,EA=71;
# MGAAC:AREA=IDSA12F,EA=71;
# MGAAC:AREA=IDSA12G,EA=71;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SAUBARA | Change de LAC=30671 para LAC=34671
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISUF01A;
# MGAAP:AREA=ISUF01B;
# MGAAP:AREA=ISUF01C;
# MGAAP:AREA=ISUF01E;
# MGAAP:AREA=ISUF01F;
# MGAAP:AREA=ISUF01G;
# MGAAP:AREA=ISUF02A;
# MGAAP:AREA=ISUF02B;
# MGAAP:AREA=ISUF02C;
# MGAAP:AREA=ISUF02E;
# MGAAP:AREA=ISUF02F;
# MGAAP:AREA=ISUF02G;
# MGAAP:AREA=ISUF02M;
# MGAAP:AREA=ISUF02N;
# MGAAP:AREA=ISUF02O;
# MGAAP:AREA=ISUF02U;
# MGAAP:AREA=ISUF02V;
# MGAAP:AREA=ISUF02W;
# MGRCP:AREA=ISUF01A;
# MGRCP:AREA=ISUF01B;
# MGRCP:AREA=ISUF01C;
# MGRCP:AREA=ISUF01E;
# MGRCP:AREA=ISUF01F;
# MGRCP:AREA=ISUF01G;
# MGRCP:AREA=ISUF02A;
# MGRCP:AREA=ISUF02B;
# MGRCP:AREA=ISUF02C;
# MGRCP:AREA=ISUF02E;
# MGRCP:AREA=ISUF02F;
# MGRCP:AREA=ISUF02G;
# MGRCP:AREA=ISUF02M;
# MGRCP:AREA=ISUF02N;
# MGRCP:AREA=ISUF02O;
# MGRCP:AREA=ISUF02U;
# MGRCP:AREA=ISUF02V;
# MGRCP:AREA=ISUF02W;
# MGAAE:AREA=ISUF01A;
# MGAAE:AREA=ISUF01B;
# MGAAE:AREA=ISUF01C;
# MGAAE:AREA=ISUF01E;
# MGAAE:AREA=ISUF01F;
# MGAAE:AREA=ISUF01G;
# MGAAE:AREA=ISUF02A;
# MGAAE:AREA=ISUF02B;
# MGAAE:AREA=ISUF02C;
# MGAAE:AREA=ISUF02E;
# MGAAE:AREA=ISUF02F;
# MGAAE:AREA=ISUF02G;
# MGAAE:AREA=ISUF02M;
# MGAAE:AREA=ISUF02N;
# MGAAE:AREA=ISUF02O;
# MGAAE:AREA=ISUF02U;
# MGAAE:AREA=ISUF02V;
# MGAAE:AREA=ISUF02W;
# MGAAI:AREA=ISUF01A,SAI=724-05-34671-60145;
# MGAAI:AREA=ISUF01B,SAI=724-05-34671-60146;
# MGAAI:AREA=ISUF01C,SAI=724-05-34671-60147;
# MGAAI:AREA=ISUF01E,SAI=724-05-34671-60148;
# MGAAI:AREA=ISUF01F,SAI=724-05-34671-60149;
# MGAAI:AREA=ISUF01G,SAI=724-05-34671-60150;
# MGAAI:AREA=ISUF02A,SAI=724-05-34671-259;
# MGAAI:AREA=ISUF02B,SAI=724-05-34671-10259;
# MGAAI:AREA=ISUF02C,SAI=724-05-34671-20259;
# MGAAI:AREA=ISUF02E,SAI=724-05-34671-64980;
# MGAAI:AREA=ISUF02F,SAI=724-05-34671-64981;
# MGAAI:AREA=ISUF02G,SAI=724-05-34671-64982;
# MGAAI:AREA=ISUF02M,SAI=724-05-34671-60240;
# MGAAI:AREA=ISUF02N,SAI=724-05-34671-60241;
# MGAAI:AREA=ISUF02O,SAI=724-05-34671-60242;
# MGAAI:AREA=ISUF02U,SAI=724-05-34671-60243;
# MGAAI:AREA=ISUF02V,SAI=724-05-34671-60244;
# MGAAI:AREA=ISUF02W,SAI=724-05-34671-60245;
# MGAAC:AREA=ISUF01A,EA=71;
# MGAAC:AREA=ISUF01B,EA=71;
# MGAAC:AREA=ISUF01C,EA=71;
# MGAAC:AREA=ISUF01E,EA=71;
# MGAAC:AREA=ISUF01F,EA=71;
# MGAAC:AREA=ISUF01G,EA=71;
# MGAAC:AREA=ISUF02A,EA=71;
# MGAAC:AREA=ISUF02B,EA=71;
# MGAAC:AREA=ISUF02C,EA=71;
# MGAAC:AREA=ISUF02E,EA=71;
# MGAAC:AREA=ISUF02F,EA=71;
# MGAAC:AREA=ISUF02G,EA=71;
# MGAAC:AREA=ISUF02M,EA=71;
# MGAAC:AREA=ISUF02N,EA=71;
# MGAAC:AREA=ISUF02O,EA=71;
# MGAAC:AREA=ISUF02U,EA=71;
# MGAAC:AREA=ISUF02V,EA=71;
# MGAAC:AREA=ISUF02W,EA=71;
#
# ! Generate emerceny center commands with AXE Tool
# True

# %% [markdown]
# ## Print "fallback" 3G commands

# %%
# Get the "fallback" commands
NOK_ERI_Toolkit.change_lai_3g_eri(my_df=df_eri_3g, my_cmd='fallback')
# Out:
# ! ARATACA | Fallback de LAC=30173 para LAC=30773
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IATW01A;
# MGAAP:AREA=IATW01B;
# MGAAP:AREA=IATW01C;
# MGAAP:AREA=IATW01E;
# MGAAP:AREA=IATW01F;
# MGAAP:AREA=IATW01G;
# MGRCP:AREA=IATW01A;
# MGRCP:AREA=IATW01B;
# MGRCP:AREA=IATW01C;
# MGRCP:AREA=IATW01E;
# MGRCP:AREA=IATW01F;
# MGRCP:AREA=IATW01G;
# MGAAE:AREA=IATW01A;
# MGAAE:AREA=IATW01B;
# MGAAE:AREA=IATW01C;
# MGAAE:AREA=IATW01E;
# MGAAE:AREA=IATW01F;
# MGAAE:AREA=IATW01G;
# MGAAI:AREA=IATW01A,SAI=724-05-30173-61050;
# MGAAI:AREA=IATW01B,SAI=724-05-30173-61051;
# MGAAI:AREA=IATW01C,SAI=724-05-30173-61052;
# MGAAI:AREA=IATW01E,SAI=724-05-30173-64650;
# MGAAI:AREA=IATW01F,SAI=724-05-30173-64651;
# MGAAI:AREA=IATW01G,SAI=724-05-30173-64652;
# MGAAC:AREA=IATW01A,EA=73;
# MGAAC:AREA=IATW01B,EA=73;
# MGAAC:AREA=IATW01C,EA=73;
# MGAAC:AREA=IATW01E,EA=73;
# MGAAC:AREA=IATW01F,EA=73;
# MGAAC:AREA=IATW01G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! BARRA | Fallback de LAC=30174 para LAC=32173
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IBAA01A;
# MGAAP:AREA=IBAA01B;
# MGAAP:AREA=IBAA01C;
# MGAAP:AREA=IBAA01E;
# MGAAP:AREA=IBAA01F;
# MGAAP:AREA=IBAA01G;
# MGAAP:AREA=IBAA03A;
# MGAAP:AREA=IBAA03B;
# MGAAP:AREA=IBAA03C;
# MGAAP:AREA=IBAA03E;
# MGAAP:AREA=IBAA03F;
# MGAAP:AREA=IBAA03G;
# MGRCP:AREA=IBAA01A;
# MGRCP:AREA=IBAA01B;
# MGRCP:AREA=IBAA01C;
# MGRCP:AREA=IBAA01E;
# MGRCP:AREA=IBAA01F;
# MGRCP:AREA=IBAA01G;
# MGRCP:AREA=IBAA03A;
# MGRCP:AREA=IBAA03B;
# MGRCP:AREA=IBAA03C;
# MGRCP:AREA=IBAA03E;
# MGRCP:AREA=IBAA03F;
# MGRCP:AREA=IBAA03G;
# MGAAE:AREA=IBAA01A;
# MGAAE:AREA=IBAA01B;
# MGAAE:AREA=IBAA01C;
# MGAAE:AREA=IBAA01E;
# MGAAE:AREA=IBAA01F;
# MGAAE:AREA=IBAA01G;
# MGAAE:AREA=IBAA03A;
# MGAAE:AREA=IBAA03B;
# MGAAE:AREA=IBAA03C;
# MGAAE:AREA=IBAA03E;
# MGAAE:AREA=IBAA03F;
# MGAAE:AREA=IBAA03G;
# MGAAI:AREA=IBAA01A,SAI=724-05-30174-62370;
# MGAAI:AREA=IBAA01B,SAI=724-05-30174-62371;
# MGAAI:AREA=IBAA01C,SAI=724-05-30174-62372;
# MGAAI:AREA=IBAA01E,SAI=724-05-30174-62373;
# MGAAI:AREA=IBAA01F,SAI=724-05-30174-62374;
# MGAAI:AREA=IBAA01G,SAI=724-05-30174-62375;
# MGAAI:AREA=IBAA03A,SAI=724-05-30174-64760;
# MGAAI:AREA=IBAA03B,SAI=724-05-30174-64761;
# MGAAI:AREA=IBAA03C,SAI=724-05-30174-64762;
# MGAAI:AREA=IBAA03E,SAI=724-05-30174-64763;
# MGAAI:AREA=IBAA03F,SAI=724-05-30174-64764;
# MGAAI:AREA=IBAA03G,SAI=724-05-30174-64765;
# MGAAC:AREA=IBAA01A,EA=73;
# MGAAC:AREA=IBAA01B,EA=73;
# MGAAC:AREA=IBAA01C,EA=73;
# MGAAC:AREA=IBAA01E,EA=73;
# MGAAC:AREA=IBAA01F,EA=73;
# MGAAC:AREA=IBAA01G,EA=73;
# MGAAC:AREA=IBAA03A,EA=73;
# MGAAC:AREA=IBAA03B,EA=73;
# MGAAC:AREA=IBAA03C,EA=73;
# MGAAC:AREA=IBAA03E,EA=73;
# MGAAC:AREA=IBAA03F,EA=73;
# MGAAC:AREA=IBAA03G,EA=73;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! JABORANDI | Fallback de LAC=30177 para LAC=33177
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IJBI04A;
# MGAAP:AREA=IJBI04E;
# MGRCP:AREA=IJBI04A;
# MGRCP:AREA=IJBI04E;
# MGAAE:AREA=IJBI04A;
# MGAAE:AREA=IJBI04E;
# MGAAI:AREA=IJBI04A,SAI=724-05-30177-30284;
# MGAAI:AREA=IJBI04E,SAI=724-05-30177-30285;
# MGAAC:AREA=IJBI04A,EA=77;
# MGAAC:AREA=IJBI04E,EA=77;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! DIAS D'ÁVILA | Fallback de LAC=30671 para LAC=32271
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=IDSA01A;
# MGAAP:AREA=IDSA01B;
# MGAAP:AREA=IDSA01C;
# MGAAP:AREA=IDSA01I;
# MGAAP:AREA=IDSA01J;
# MGAAP:AREA=IDSA01K;
# MGAAP:AREA=IDSA02A;
# MGAAP:AREA=IDSA02B;
# MGAAP:AREA=IDSA02C;
# MGAAP:AREA=IDSA02I;
# MGAAP:AREA=IDSA02J;
# MGAAP:AREA=IDSA02K;
# MGAAP:AREA=IDSA03A;
# MGAAP:AREA=IDSA03B;
# MGAAP:AREA=IDSA03C;
# MGAAP:AREA=IDSA03I;
# MGAAP:AREA=IDSA03J;
# MGAAP:AREA=IDSA03K;
# MGAAP:AREA=IDSA04A;
# MGAAP:AREA=IDSA04B;
# MGAAP:AREA=IDSA04C;
# MGAAP:AREA=IDSA04I;
# MGAAP:AREA=IDSA04J;
# MGAAP:AREA=IDSA04K;
# MGAAP:AREA=IDSA08A;
# MGAAP:AREA=IDSA08B;
# MGAAP:AREA=IDSA08C;
# MGAAP:AREA=IDSA08E;
# MGAAP:AREA=IDSA08F;
# MGAAP:AREA=IDSA08G;
# MGAAP:AREA=IDSA09A;
# MGAAP:AREA=IDSA09B;
# MGAAP:AREA=IDSA09C;
# MGAAP:AREA=IDSA09E;
# MGAAP:AREA=IDSA09F;
# MGAAP:AREA=IDSA09G;
# MGAAP:AREA=IDSA10A;
# MGAAP:AREA=IDSA10B;
# MGAAP:AREA=IDSA10C;
# MGAAP:AREA=IDSA10E;
# MGAAP:AREA=IDSA10F;
# MGAAP:AREA=IDSA10G;
# MGAAP:AREA=IDSA12A;
# MGAAP:AREA=IDSA12B;
# MGAAP:AREA=IDSA12C;
# MGAAP:AREA=IDSA12E;
# MGAAP:AREA=IDSA12F;
# MGAAP:AREA=IDSA12G;
# MGRCP:AREA=IDSA01A;
# MGRCP:AREA=IDSA01B;
# MGRCP:AREA=IDSA01C;
# MGRCP:AREA=IDSA01I;
# MGRCP:AREA=IDSA01J;
# MGRCP:AREA=IDSA01K;
# MGRCP:AREA=IDSA02A;
# MGRCP:AREA=IDSA02B;
# MGRCP:AREA=IDSA02C;
# MGRCP:AREA=IDSA02I;
# MGRCP:AREA=IDSA02J;
# MGRCP:AREA=IDSA02K;
# MGRCP:AREA=IDSA03A;
# MGRCP:AREA=IDSA03B;
# MGRCP:AREA=IDSA03C;
# MGRCP:AREA=IDSA03I;
# MGRCP:AREA=IDSA03J;
# MGRCP:AREA=IDSA03K;
# MGRCP:AREA=IDSA04A;
# MGRCP:AREA=IDSA04B;
# MGRCP:AREA=IDSA04C;
# MGRCP:AREA=IDSA04I;
# MGRCP:AREA=IDSA04J;
# MGRCP:AREA=IDSA04K;
# MGRCP:AREA=IDSA08A;
# MGRCP:AREA=IDSA08B;
# MGRCP:AREA=IDSA08C;
# MGRCP:AREA=IDSA08E;
# MGRCP:AREA=IDSA08F;
# MGRCP:AREA=IDSA08G;
# MGRCP:AREA=IDSA09A;
# MGRCP:AREA=IDSA09B;
# MGRCP:AREA=IDSA09C;
# MGRCP:AREA=IDSA09E;
# MGRCP:AREA=IDSA09F;
# MGRCP:AREA=IDSA09G;
# MGRCP:AREA=IDSA10A;
# MGRCP:AREA=IDSA10B;
# MGRCP:AREA=IDSA10C;
# MGRCP:AREA=IDSA10E;
# MGRCP:AREA=IDSA10F;
# MGRCP:AREA=IDSA10G;
# MGRCP:AREA=IDSA12A;
# MGRCP:AREA=IDSA12B;
# MGRCP:AREA=IDSA12C;
# MGRCP:AREA=IDSA12E;
# MGRCP:AREA=IDSA12F;
# MGRCP:AREA=IDSA12G;
# MGAAE:AREA=IDSA01A;
# MGAAE:AREA=IDSA01B;
# MGAAE:AREA=IDSA01C;
# MGAAE:AREA=IDSA01I;
# MGAAE:AREA=IDSA01J;
# MGAAE:AREA=IDSA01K;
# MGAAE:AREA=IDSA02A;
# MGAAE:AREA=IDSA02B;
# MGAAE:AREA=IDSA02C;
# MGAAE:AREA=IDSA02I;
# MGAAE:AREA=IDSA02J;
# MGAAE:AREA=IDSA02K;
# MGAAE:AREA=IDSA03A;
# MGAAE:AREA=IDSA03B;
# MGAAE:AREA=IDSA03C;
# MGAAE:AREA=IDSA03I;
# MGAAE:AREA=IDSA03J;
# MGAAE:AREA=IDSA03K;
# MGAAE:AREA=IDSA04A;
# MGAAE:AREA=IDSA04B;
# MGAAE:AREA=IDSA04C;
# MGAAE:AREA=IDSA04I;
# MGAAE:AREA=IDSA04J;
# MGAAE:AREA=IDSA04K;
# MGAAE:AREA=IDSA08A;
# MGAAE:AREA=IDSA08B;
# MGAAE:AREA=IDSA08C;
# MGAAE:AREA=IDSA08E;
# MGAAE:AREA=IDSA08F;
# MGAAE:AREA=IDSA08G;
# MGAAE:AREA=IDSA09A;
# MGAAE:AREA=IDSA09B;
# MGAAE:AREA=IDSA09C;
# MGAAE:AREA=IDSA09E;
# MGAAE:AREA=IDSA09F;
# MGAAE:AREA=IDSA09G;
# MGAAE:AREA=IDSA10A;
# MGAAE:AREA=IDSA10B;
# MGAAE:AREA=IDSA10C;
# MGAAE:AREA=IDSA10E;
# MGAAE:AREA=IDSA10F;
# MGAAE:AREA=IDSA10G;
# MGAAE:AREA=IDSA12A;
# MGAAE:AREA=IDSA12B;
# MGAAE:AREA=IDSA12C;
# MGAAE:AREA=IDSA12E;
# MGAAE:AREA=IDSA12F;
# MGAAE:AREA=IDSA12G;
# MGAAI:AREA=IDSA01A,SAI=724-05-30671-115;
# MGAAI:AREA=IDSA01B,SAI=724-05-30671-10115;
# MGAAI:AREA=IDSA01C,SAI=724-05-30671-20115;
# MGAAI:AREA=IDSA01I,SAI=724-05-30671-40115;
# MGAAI:AREA=IDSA01J,SAI=724-05-30671-50115;
# MGAAI:AREA=IDSA01K,SAI=724-05-30671-60115;
# MGAAI:AREA=IDSA02A,SAI=724-05-30671-215;
# MGAAI:AREA=IDSA02B,SAI=724-05-30671-10215;
# MGAAI:AREA=IDSA02C,SAI=724-05-30671-20215;
# MGAAI:AREA=IDSA02I,SAI=724-05-30671-40215;
# MGAAI:AREA=IDSA02J,SAI=724-05-30671-50215;
# MGAAI:AREA=IDSA02K,SAI=724-05-30671-60215;
# MGAAI:AREA=IDSA03A,SAI=724-05-30671-315;
# MGAAI:AREA=IDSA03B,SAI=724-05-30671-10315;
# MGAAI:AREA=IDSA03C,SAI=724-05-30671-20315;
# MGAAI:AREA=IDSA03I,SAI=724-05-30671-40315;
# MGAAI:AREA=IDSA03J,SAI=724-05-30671-50315;
# MGAAI:AREA=IDSA03K,SAI=724-05-30671-60315;
# MGAAI:AREA=IDSA04A,SAI=724-05-30671-415;
# MGAAI:AREA=IDSA04B,SAI=724-05-30671-10415;
# MGAAI:AREA=IDSA04C,SAI=724-05-30671-20415;
# MGAAI:AREA=IDSA04I,SAI=724-05-30671-40415;
# MGAAI:AREA=IDSA04J,SAI=724-05-30671-50415;
# MGAAI:AREA=IDSA04K,SAI=724-05-30671-60415;
# MGAAI:AREA=IDSA08A,SAI=724-05-30671-60012;
# MGAAI:AREA=IDSA08B,SAI=724-05-30671-60013;
# MGAAI:AREA=IDSA08C,SAI=724-05-30671-60014;
# MGAAI:AREA=IDSA08E,SAI=724-05-30671-60015;
# MGAAI:AREA=IDSA08F,SAI=724-05-30671-60016;
# MGAAI:AREA=IDSA08G,SAI=724-05-30671-60017;
# MGAAI:AREA=IDSA09A,SAI=724-05-30671-60037;
# MGAAI:AREA=IDSA09B,SAI=724-05-30671-60038;
# MGAAI:AREA=IDSA09C,SAI=724-05-30671-60039;
# MGAAI:AREA=IDSA09E,SAI=724-05-30671-60040;
# MGAAI:AREA=IDSA09F,SAI=724-05-30671-60041;
# MGAAI:AREA=IDSA09G,SAI=724-05-30671-60042;
# MGAAI:AREA=IDSA10A,SAI=724-05-30671-60940;
# MGAAI:AREA=IDSA10B,SAI=724-05-30671-60941;
# MGAAI:AREA=IDSA10C,SAI=724-05-30671-60942;
# MGAAI:AREA=IDSA10E,SAI=724-05-30671-60943;
# MGAAI:AREA=IDSA10F,SAI=724-05-30671-60944;
# MGAAI:AREA=IDSA10G,SAI=724-05-30671-60945;
# MGAAI:AREA=IDSA12A,SAI=724-05-30671-60362;
# MGAAI:AREA=IDSA12B,SAI=724-05-30671-60363;
# MGAAI:AREA=IDSA12C,SAI=724-05-30671-60364;
# MGAAI:AREA=IDSA12E,SAI=724-05-30671-60365;
# MGAAI:AREA=IDSA12F,SAI=724-05-30671-60366;
# MGAAI:AREA=IDSA12G,SAI=724-05-30671-60367;
# MGAAC:AREA=IDSA01A,EA=71;
# MGAAC:AREA=IDSA01B,EA=71;
# MGAAC:AREA=IDSA01C,EA=71;
# MGAAC:AREA=IDSA01I,EA=71;
# MGAAC:AREA=IDSA01J,EA=71;
# MGAAC:AREA=IDSA01K,EA=71;
# MGAAC:AREA=IDSA02A,EA=71;
# MGAAC:AREA=IDSA02B,EA=71;
# MGAAC:AREA=IDSA02C,EA=71;
# MGAAC:AREA=IDSA02I,EA=71;
# MGAAC:AREA=IDSA02J,EA=71;
# MGAAC:AREA=IDSA02K,EA=71;
# MGAAC:AREA=IDSA03A,EA=71;
# MGAAC:AREA=IDSA03B,EA=71;
# MGAAC:AREA=IDSA03C,EA=71;
# MGAAC:AREA=IDSA03I,EA=71;
# MGAAC:AREA=IDSA03J,EA=71;
# MGAAC:AREA=IDSA03K,EA=71;
# MGAAC:AREA=IDSA04A,EA=71;
# MGAAC:AREA=IDSA04B,EA=71;
# MGAAC:AREA=IDSA04C,EA=71;
# MGAAC:AREA=IDSA04I,EA=71;
# MGAAC:AREA=IDSA04J,EA=71;
# MGAAC:AREA=IDSA04K,EA=71;
# MGAAC:AREA=IDSA08A,EA=71;
# MGAAC:AREA=IDSA08B,EA=71;
# MGAAC:AREA=IDSA08C,EA=71;
# MGAAC:AREA=IDSA08E,EA=71;
# MGAAC:AREA=IDSA08F,EA=71;
# MGAAC:AREA=IDSA08G,EA=71;
# MGAAC:AREA=IDSA09A,EA=71;
# MGAAC:AREA=IDSA09B,EA=71;
# MGAAC:AREA=IDSA09C,EA=71;
# MGAAC:AREA=IDSA09E,EA=71;
# MGAAC:AREA=IDSA09F,EA=71;
# MGAAC:AREA=IDSA09G,EA=71;
# MGAAC:AREA=IDSA10A,EA=71;
# MGAAC:AREA=IDSA10B,EA=71;
# MGAAC:AREA=IDSA10C,EA=71;
# MGAAC:AREA=IDSA10E,EA=71;
# MGAAC:AREA=IDSA10F,EA=71;
# MGAAC:AREA=IDSA10G,EA=71;
# MGAAC:AREA=IDSA12A,EA=71;
# MGAAC:AREA=IDSA12B,EA=71;
# MGAAC:AREA=IDSA12C,EA=71;
# MGAAC:AREA=IDSA12E,EA=71;
# MGAAC:AREA=IDSA12F,EA=71;
# MGAAC:AREA=IDSA12G,EA=71;
#
# ! Generate emerceny center commands with AXE Tool
#
# ! SAUBARA | Fallback de LAC=30671 para LAC=34671
# !--------------------------------------------------------------------------------------
# MGAAP:AREA=ISUF01A;
# MGAAP:AREA=ISUF01B;
# MGAAP:AREA=ISUF01C;
# MGAAP:AREA=ISUF01E;
# MGAAP:AREA=ISUF01F;
# MGAAP:AREA=ISUF01G;
# MGAAP:AREA=ISUF02A;
# MGAAP:AREA=ISUF02B;
# MGAAP:AREA=ISUF02C;
# MGAAP:AREA=ISUF02E;
# MGAAP:AREA=ISUF02F;
# MGAAP:AREA=ISUF02G;
# MGAAP:AREA=ISUF02M;
# MGAAP:AREA=ISUF02N;
# MGAAP:AREA=ISUF02O;
# MGAAP:AREA=ISUF02U;
# MGAAP:AREA=ISUF02V;
# MGAAP:AREA=ISUF02W;
# MGRCP:AREA=ISUF01A;
# MGRCP:AREA=ISUF01B;
# MGRCP:AREA=ISUF01C;
# MGRCP:AREA=ISUF01E;
# MGRCP:AREA=ISUF01F;
# MGRCP:AREA=ISUF01G;
# MGRCP:AREA=ISUF02A;
# MGRCP:AREA=ISUF02B;
# MGRCP:AREA=ISUF02C;
# MGRCP:AREA=ISUF02E;
# MGRCP:AREA=ISUF02F;
# MGRCP:AREA=ISUF02G;
# MGRCP:AREA=ISUF02M;
# MGRCP:AREA=ISUF02N;
# MGRCP:AREA=ISUF02O;
# MGRCP:AREA=ISUF02U;
# MGRCP:AREA=ISUF02V;
# MGRCP:AREA=ISUF02W;
# MGAAE:AREA=ISUF01A;
# MGAAE:AREA=ISUF01B;
# MGAAE:AREA=ISUF01C;
# MGAAE:AREA=ISUF01E;
# MGAAE:AREA=ISUF01F;
# MGAAE:AREA=ISUF01G;
# MGAAE:AREA=ISUF02A;
# MGAAE:AREA=ISUF02B;
# MGAAE:AREA=ISUF02C;
# MGAAE:AREA=ISUF02E;
# MGAAE:AREA=ISUF02F;
# MGAAE:AREA=ISUF02G;
# MGAAE:AREA=ISUF02M;
# MGAAE:AREA=ISUF02N;
# MGAAE:AREA=ISUF02O;
# MGAAE:AREA=ISUF02U;
# MGAAE:AREA=ISUF02V;
# MGAAE:AREA=ISUF02W;
# MGAAI:AREA=ISUF01A,SAI=724-05-30671-60145;
# MGAAI:AREA=ISUF01B,SAI=724-05-30671-60146;
# MGAAI:AREA=ISUF01C,SAI=724-05-30671-60147;
# MGAAI:AREA=ISUF01E,SAI=724-05-30671-60148;
# MGAAI:AREA=ISUF01F,SAI=724-05-30671-60149;
# MGAAI:AREA=ISUF01G,SAI=724-05-30671-60150;
# MGAAI:AREA=ISUF02A,SAI=724-05-30671-259;
# MGAAI:AREA=ISUF02B,SAI=724-05-30671-10259;
# MGAAI:AREA=ISUF02C,SAI=724-05-30671-20259;
# MGAAI:AREA=ISUF02E,SAI=724-05-30671-64980;
# MGAAI:AREA=ISUF02F,SAI=724-05-30671-64981;
# MGAAI:AREA=ISUF02G,SAI=724-05-30671-64982;
# MGAAI:AREA=ISUF02M,SAI=724-05-30671-60240;
# MGAAI:AREA=ISUF02N,SAI=724-05-30671-60241;
# MGAAI:AREA=ISUF02O,SAI=724-05-30671-60242;
# MGAAI:AREA=ISUF02U,SAI=724-05-30671-60243;
# MGAAI:AREA=ISUF02V,SAI=724-05-30671-60244;
# MGAAI:AREA=ISUF02W,SAI=724-05-30671-60245;
# MGAAC:AREA=ISUF01A,EA=71;
# MGAAC:AREA=ISUF01B,EA=71;
# MGAAC:AREA=ISUF01C,EA=71;
# MGAAC:AREA=ISUF01E,EA=71;
# MGAAC:AREA=ISUF01F,EA=71;
# MGAAC:AREA=ISUF01G,EA=71;
# MGAAC:AREA=ISUF02A,EA=71;
# MGAAC:AREA=ISUF02B,EA=71;
# MGAAC:AREA=ISUF02C,EA=71;
# MGAAC:AREA=ISUF02E,EA=71;
# MGAAC:AREA=ISUF02F,EA=71;
# MGAAC:AREA=ISUF02G,EA=71;
# MGAAC:AREA=ISUF02M,EA=71;
# MGAAC:AREA=ISUF02N,EA=71;
# MGAAC:AREA=ISUF02O,EA=71;
# MGAAC:AREA=ISUF02U,EA=71;
# MGAAC:AREA=ISUF02V,EA=71;
# MGAAC:AREA=ISUF02W,EA=71;
#
# ! Generate emerceny center commands with AXE Tool
# True
